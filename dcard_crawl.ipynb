# %%
import requests
import json

if __name__ == '__main__':
    resp = requests.get('http://dcard.tw/_api/forums')
    print(resp)
# Out:
# <Response [403]>

# %%
import requests
from bs4 import BeautifulSoup  #导入所需库

url = 'https://tw.observer/search/＃感情'
headers = {
      'User-Agent':"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; rv:2.0.1) Gecko/20100101 Firefox/4.0.1"
}
res = requests.get(url,headers=headers)
soup = BeautifulSoup(res.text) #印出段落p內文

# title = soup.find_all(class_='body')
title = soup.find_all(["title", "p"])
for tr in title:
    print("-----")
    print(tr)

# urls = []
# for i in soup.find_all(class_="body")[0].find_all("text"):
#     url = i.get("src")
#     if len(url)< 96:
#         with open(url.split("/")[-1],"wb+") as f:
#             headers = {"Referer":url}
#             f.write(requests.get(url,headers=headers).content)
# print("==========图片下载完成，快去做你该做的事情=========")
# Out:
# -----
# <title>「＃感情」的搜尋結果 - 深卡</title>
# -----
# <p><span class="embed"><img alt="🖼️" class="emojione" src="https://cdn.jsdelivr.net/emojione/assets/3.1/png/128/1f5bc.png"/></span>在一起快1000天 好的壞的都經歷過 謝謝你陪著我走過高中 到我大學還對我無微不至的照顧 看到什麼東西都會想到我 除了上班 其他時間都想陪我 可以說你的生活除了家人 就只剩下我了… 這2年多你一直包容我的臭脾氣 把我捧在手心上呵護 帶我回家介紹給你家人認識 我真的很幸運可以遇到你 很多人都說我們這麼穩定 一定可以走到最後 甚至結婚 我們都為這段感情 彼此努力過了 但對不起因為我的問題 我們在今天 白色情人節前一天分手了 我哭的真的超慘 因為我知道你有多愛我 你卻因為愛我 不想耽誤我 當你這樣對我說 我就又爆哭了 可是你當下沒有哭 我問你為什麼沒有難過 你跟我說 「如果我也哭了，誰來安慰你。」 連到最後都在為我著想.. 你為什麼要對我這麼好.. 不管我們是什麼關係 你對我來說都很重要 有什麼事情你告訴我 我一定會為你奮不顧身 就像你對我那樣一樣 希望你可以找到比我更好的女孩 你真的真的值得更好的 我知道我不是很好的女朋友 但你當我男朋友 真的做的很好了 謝謝你愛我 我也愛你 我想這份愛已經昇華成親情 對家人的愛了吧 願你幸福 一定要比我更幸福</p>
# -----
# ...

# %%
url = 'https://tw.observer/search/＃感情'
headers = {
      'User-Agent':"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; rv:2.0.1) Gecko/20100101 Firefox/4.0.1"
}
res = requests.get(url,headers=headers)
soup = BeautifulSoup(res.text) #印出段落p內文

a_tags = soup.find_all('p')
for tag in a_tags:
    print('-----')
    print(tag)
#     print(tag.string)
# Out:
# -----
# <p><span class="embed"><img alt="🖼️" class="emojione" src="https://cdn.jsdelivr.net/emojione/assets/3.1/png/128/1f5bc.png"/></span>在一起快1000天 好的壞的都經歷過 謝謝你陪著我走過高中 到我大學還對我無微不至的照顧 看到什麼東西都會想到我 除了上班 其他時間都想陪我 可以說你的生活除了家人 就只剩下我了… 這2年多你一直包容我的臭脾氣 把我捧在手心上呵護 帶我回家介紹給你家人認識 我真的很幸運可以遇到你 很多人都說我們這麼穩定 一定可以走到最後 甚至結婚 我們都為這段感情 彼此努力過了 但對不起因為我的問題 我們在今天 白色情人節前一天分手了 我哭的真的超慘 因為我知道你有多愛我 你卻因為愛我 不想耽誤我 當你這樣對我說 我就又爆哭了 可是你當下沒有哭 我問你為什麼沒有難過 你跟我說 「如果我也哭了，誰來安慰你。」 連到最後都在為我著想.. 你為什麼要對我這麼好.. 不管我們是什麼關係 你對我來說都很重要 有什麼事情你告訴我 我一定會為你奮不顧身 就像你對我那樣一樣 希望你可以找到比我更好的女孩 你真的真的值得更好的 我知道我不是很好的女朋友 但你當我男朋友 真的做的很好了 謝謝你愛我 我也愛你 我想這份愛已經昇華成親情 對家人的愛了吧 願你幸福 一定要比我更幸福</p>
# -----
# ...

# %%
url = 'https://tw.observer/search/＃股票'
headers = {
      'User-Agent':"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; rv:2.0.1) Gecko/20100101 Firefox/4.0.1"
}
res = requests.get(url,headers=headers)
soup = BeautifulSoup(res.text) #印出段落p內文

a_tags = soup.find_all('p')
for tag in a_tags:
    print('\n-------------------------')
    print(tag.text)
# Out:
# -------------------------
# 因為有人問我為什麼美軍參戰俄烏會需要存石油股，短暫整理了一下。 直接展開來說了 1是美軍參戰會照成世界三大產油國中的其二美國與俄國成為打仗的國家，供給端不管有沒有問題都會被當成只剩下沙國比較穩定。 2能源價格不跟隨戰事升高的唯一一個可能性是各大國退出Swift美元結算系統，但如果去問各國金融系統不可能說變就變，眾資產可都還在美國，尤其是中國。 3 拜登已經在今天強調對俄國是「Long Fight」長期戰爭，符合之前的預測，也是很重要的一點美國政府想要高能源價格，為了推展電動車。也只有高能源價格可以提升民眾自發買電動車卻不動用政府的錢袋（也就是不動用政府補助） 4目前可以肯定高能源價格會是長期的，到2024都還有往上成長的空間，且因為戰事的延長支撐了上升趨勢。 5現代人從燃油車到電動車的轉換能負擔的起的還是只有前面幾%，燃油車還能持續使用很長一段時間，就算十年過後全球也只能擴展到30%的使用量，現在0.5%。這緩慢的轉換過程人們並不清楚，但可以讓政治人物有更多理由去維持高油價來將降低美國本土的國債問題。因為石油相當於美金，都具有將經濟風險規避給全世界的功能。
#
# -------------------------
# ...
