# %%
import os
import pandas as pd
import matplotlib.pyplot as plt 
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Source
#
# https://www.kaggle.com/competitions/fake-news-pair-classification-challenge/data
#
# RoBERTa: A Robustly Optimized BERT Pretraining Approach
#
# https://leemeng.tw/shortest-path-to-the-nlp-world-a-gentle-guide-of-natural-language-processing-and-deep-learning-for-everyone.html
#
# https://leemeng.tw/attack_on_bert_transfer_learning_in_nlp.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Step 1: 資料前處理
#
# 1. Jieba 中文斷詞
# 2. 將文本轉成數字序列 -> Keras Tokenizer
# 3. 序列長度統一 -> Keras pad_sequences (zero padding)
# 4. 把label做encoding -> Keras One-hot Encoding
# 5. 切割訓練資料集 & 驗證資料集 -> scikit-learn 中的 train_test_split
#
# # Step 2: LSTM
#
# 1. 將數字序列透過Backpropagation進行Word Embedding，轉換成vector -> Keras Embedding
#
#
# # Step 3: Loss function & Optimize
