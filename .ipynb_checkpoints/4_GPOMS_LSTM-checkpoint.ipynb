# %%
import datetime
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evaluation
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
import tensorflow as tf 
from scipy import stats

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
import itertools

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # I. Load data

# %%
OF = pd.read_pickle("Related_dataset/Opinion_Finder_result.pkl")
GPOMS = pd.read_pickle("Related_dataset/GPOMS_result.pkl")
DJIA = pd.read_pickle("Related_dataset/DJIA_filled_missing_value.pkl")

# %% [markdown]
# # 2. Prepare dataset

# %%
# process GPOMS dataframe
GPOMS_pivot = GPOMS.drop(columns=['tweets_processed', 'tweet_size', 'GPOMS_preprocess_data', 'GPOMS_sum','sum_index', 'avg_index'])
GPOMS_pivot[['Calm','Kind','Happy','Alert','Sure','Vital']] = pd.DataFrame(GPOMS.GPOMS_avg.tolist(), index= GPOMS.index)
GPOMS_pivot = GPOMS_pivot.drop(['GPOMS_avg'], axis=1)
GPOMS_pivot = GPOMS_pivot.reset_index()
GPOMS_pivot = GPOMS_pivot.rename({'date_prune': 'Dates'}, axis=1) 

# process DJIA dataframe
DJIA['Dates'] = DJIA['Dates'].astype(str)

combine_df = DJIA.merge(GPOMS_pivot, on='Dates')
combine_df
# Out:
#          Dates         Close      Calm      Kind     Happy     Alert  \
# 0   2020-04-09  23719.369141  0.073364  0.191523 -0.115305  0.346767
# 1   2020-04-10  23555.069336  0.092862  0.195467 -0.102743  0.342314
# 2   2020-04-11  23472.919434  0.061887  0.278887 -0.064833  0.340592
# 3   2020-04-12  23431.844482  0.082763  0.216780 -0.062001  0.329557
# 4   2020-04-13  23390.769531  0.079693  0.222743 -0.091400  0.338160
# ..         ...           ...       ...       ...       ...       ...
# 72  2020-07-12  26083.175781  0.078391  0.181213 -0.097056  0.369545
# 73  2020-07-13  26085.800781  0.082311  0.183053 -0.082040  0.357759
# 74  2020-07-14  26642.589844  0.098220  0.186504 -0.089044  0.359141
# 75  2020-07-15  26870.099609  0.084568  0.184610 -0.079527  0.337375
# 76  2020-07-16  26734.710938  0.080464  0.185802 -0.098970  0.355024
#
#         Sure     Vital
# 0   0.136158  0.155670
# 1   0.130042  0.118410
# 2   0.101464  0.160457
# 3   0.111304  0.079260
# 4   0.130949  0.137338
# ..       ...       ...
# 72  0.147573  0.078480
# 73  0.154204  0.122646
# 74  0.150973  0.111742
# 75  0.146182  0.102206
# 76  0.149060  0.099416
#
# [77 rows x 8 columns]

# %% [markdown]
# # III. Build Neural Network model to predict DJIA
# input:
# 1. The past 3 days of DJIA values
# 2. Opinion Finder mood data (past 3 days)
#
# Time period (in thesis):
# > Train: 2008-2-28 ~ 2008-11-28 (10 months)
#
# > Test: 2008-12-1 ~ 2008-12-19 (19 days)
#
# Time period (in this project):
# > Train: 2020-4-9 ~ 2020-6-23 (54 days, some missing data)
#
# > Test: 2020-6-24 ~ 2022-7-16 (20 days)

# %%
threshold = 54

# %% [markdown]
# ### Part 2: 提供過去3天的DJIA + GPOMS 資料:
#
# multi-variable
#
# > X[0]: [[ [1-1, 1-2, ..], [2-1, 2-2, ...], [3-1, 3-2, ...]]]
#
# > y[0]: [4]

# %%
temp2 = combine_df.set_index('Dates')
mms_close = MinMaxScaler()
mms_calm = MinMaxScaler()
mms_kind = MinMaxScaler()
mms_happy = MinMaxScaler()
mms_alert = MinMaxScaler()
mms_sure = MinMaxScaler()
mms_vital = MinMaxScaler()
mms_delta = MinMaxScaler()

temp2['Close'] = mms_close.fit_transform(np.array(temp2['Close']).reshape(-1, 1))
temp2['Calm'] = mms_calm.fit_transform(np.array(temp2['Calm']).reshape(-1, 1))
temp2['Kind'] = mms_kind.fit_transform(np.array(temp2['Kind']).reshape(-1, 1))
temp2['Happy'] = mms_happy.fit_transform(np.array(temp2['Happy']).reshape(-1, 1))
temp2['Alert'] = mms_alert.fit_transform(np.array(temp2['Alert']).reshape(-1, 1))
temp2['Sure'] = mms_sure.fit_transform(np.array(temp2['Sure']).reshape(-1, 1))
temp2['Vital'] = mms_vital.fit_transform(np.array(temp2['Vital']).reshape(-1, 1))

temp2.head()
# Out:
#                Close      Calm      Kind     Happy     Alert      Sure  \
# Dates
# 2020-04-09  0.153833  0.710392  0.416849  0.471563  0.458773  0.248355
# 2020-04-10  0.117752  0.838021  0.443179  0.596098  0.437843  0.204577
# 2020-04-11  0.099711  0.635268  1.000000  0.971922  0.429748  0.000000
# 2020-04-12  0.090690  0.771914  0.585441  1.000000  0.377869  0.070439
# 2020-04-13  0.081670  0.751823  0.625244  0.708548  0.418315  0.211071
#
#                Vital
# Dates
# 2020-04-09  0.778378
# 2020-04-10  0.468202
# 2020-04-11  0.818231
# 2020-04-12  0.142280
# 2020-04-13  0.625771

# %%
def df_to_X_y2(df, window_size=3):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 3
NUM_FEATURE = 7

X2, y2 = df_to_X_y2(temp2, WINDOW_SIZE)
X2.shape, y2.shape # number of data, # size of window, number of features
# Out:
# ((74, 3, 7), (74,))

# %%
X_train2, y_train2 = X2[:threshold-3], y2[:threshold-3]
X_test2, y_test2 = X2[threshold:], y2[threshold:]
X_train2.shape, y_train2.shape, X_test2.shape, y_test2.shape
# Out:
# ((51, 3, 7), (51,), (20, 3, 7), (20,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, NUM_FEATURE)))
model2.add(LSTM(64))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 64)                18432
#
#  dense_4 (Dense)             (None, 8)                 520
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 18,961
# Trainable params: 18,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])
model2.fit(X_train2, y_train2, epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.1758 - root_mean_squared_error: 0.4193
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1555 - root_mean_squared_error: 0.3943
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0809 - root_mean_squared_error: 0.2845
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0692 - root_mean_squared_error: 0.2631
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0561 - root_mean_squared_error: 0.2368
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0382 - root_mean_squared_error: 0.1955
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0299 - root_mean_squared_error: 0.1729
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0244 - root_mean_squared_error: 0.1561
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234

# %%
def plot_modal_res(df, tp):
    plt.title(f"{tp} result")
    plt.plot(df[f'{tp} Predictions'], c='b')
    plt.plot(df['Actuals'], c='g')
    plt.legend(["Modal Predict", "Ground True"], loc ="lower right")
    plt.show()

# %%
# train result
train_predictions2 = model2.predict(X_train2).flatten()
pred = mms_close.inverse_transform(train_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_train2.reshape(-1, 1))
act = act.reshape(-1,)

train_results2 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

plot_modal_res(train_results2,'Train')
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
# Test result
test_predictions2 = model2.predict(X_test2).flatten()
pred = mms_close.inverse_transform(test_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_test2.reshape(-1, 1))
act = act.reshape(-1,)

test_results2 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})

plot_modal_res(test_results2,'Test')
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# # IV. Compute MAPE & Direction correct rate

# %%
def mape(actual, predict): 
    actual, predict = np.array(actual), np.array(predict)
    return np.mean(np.abs((actual - predict) / actual)) * 100

def direction(actual, predict): 
    prev_act = actual[0]
    prev_pred = predict[0]
    true = []
    res = []
    for i, j in zip(actual[1:], predict[1:]): 
        if i>=prev_act:
            true.append(1)
        else:
            true.append(-1)
        if j>=prev_pred:
            res.append(1)
        else:
            res.append(-1)
        prev_act = i
        prev_pred = j
    denorminator = len(actual) -1
    numerator = 0
    for i, j in zip(true, res):
        if i==j:
            numerator += 1
    return (numerator / denorminator)

# %%
test_results2
# Out:
#     Test Predictions       Actuals
# 0       31442.160156  30364.830078
# 1       31515.955078  30668.529297
# 2       31653.019531  29927.070312
# 3       31601.634766  29888.779297
# 4       31527.402344  30209.514648
# 5       31556.544922  30369.882324
# 6       31617.861328  30450.066162
# 7       31473.224609  30530.250000
# 8       31520.527344  30483.130859
# 9       31580.884766  30677.359375
# 10      31739.134766  31500.679688
# 11      31726.626953  31469.469727
# 12      31842.888672  31453.864746
# 13      31755.472656  31438.259766
# 14      31875.775391  30946.990234
# 15      31787.675781  31029.310547
# 16      31753.988281  30775.429688

# %%
# Part 2: past three days' DJIA data + GPOMS
print("MAPE: ", mape(test_results2['Actuals'], test_results2['Test Predictions']).round(3), "%")
print("Directional correction rate:", "{0:.0%}".format(direction(test_results2['Actuals'], test_results2['Test Predictions'])) )
# Out:
# MAPE:  1.252 %
# Directional correction rate: 58%

# %%
plot_modal_res(test_results2,'Test')

# %% [markdown]
# reference:
#
# https://colab.research.google.com/drive/1b3CUJuDOmPmNdZFH3LQDmt5F0K3FZhqD?usp=sharing#scrollTo=FmwshpETs-jE

# %% [markdown]
# # PART2

# %%
type = combine_df.columns[2:]
type
# Out:
# Index(['Calm', 'Kind', 'Happy', 'Alert', 'Sure', 'Vital'], dtype='object')

# %%
for t in type:
    print(t,":", sum(combine_df[t].abs()))
# Out:
# Calm : 6.137272709997564
# Kind : 14.431125332832584
# Happy : 7.953537386059971
# Alert : 27.188878523597204
# Sure : 11.079659708547513
# Vital : 9.597250700694977

# %%
def eval(results):
    MAPE = mape(results['Actuals'], results['Test Predictions']).round(3)
    Direction =  direction(results['Actuals'], results['Test Predictions'])
    return MAPE, Direction

# %%
finish = []

num = [2, 3, 4, 5, 6, 7]
for j in num:
    NUM_FEATURE = j
    sum = list(itertools.combinations(type, NUM_FEATURE-1))

    for i in sum:
        k = ['Close']+list(i)
        tmp = temp2[k]

        WINDOW_SIZE = 3

        X2, y2 = df_to_X_y2(tmp, WINDOW_SIZE)
        X2.shape, y2.shape # number of data, # size of window, number of features

        X_train2, y_train2 = X2[:threshold-3], y2[:threshold-3]
        X_test2, y_test2 = X2[threshold:], y2[threshold:]
        X_train2.shape, y_train2.shape, X_test2.shape, y_test2.shape

        model2 = Sequential()
        model2.add(InputLayer((WINDOW_SIZE, NUM_FEATURE)))
        model2.add(LSTM(64))
        model2.add(Dense(8, 'relu'))
        model2.add(Dense(1, 'linear'))
        model2.summary()

        model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])
        model2.fit(X_train2, y_train2, epochs=10)

        # train result
        train_predictions2 = model2.predict(X_train2).flatten()
        pred = mms_close.inverse_transform(train_predictions2.reshape(-1, 1))
        pred = pred.reshape(-1,)
        act = mms_close.inverse_transform(y_train2.reshape(-1, 1))
        act = act.reshape(-1,)

        train_results2 = pd.DataFrame(data={
            'Train Predictions':pred, 
            'Actuals':act})

        # Test result
        test_predictions2 = model2.predict(X_test2).flatten()
        pred = mms_close.inverse_transform(test_predictions2.reshape(-1, 1))
        pred = pred.reshape(-1,)
        act = mms_close.inverse_transform(y_test2.reshape(-1, 1))
        act = act.reshape(-1,)

        test_results2 = pd.DataFrame(data={
            'Test Predictions':pred, 
            'Actuals':act})
        
        e1, e2 = eval(test_results2)
        finish.append([i, e1, e2])
        del model2
# Out:
# Model: "sequential_72"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_72 (LSTM)              (None, 64)                17152
#
#  dense_144 (Dense)           (None, 8)                 520
#
#  dense_145 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,681
# Trainable params: 17,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1451 - root_mean_squared_error: 0.3809
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0609 - root_mean_squared_error: 0.2467
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0372 - root_mean_squared_error: 0.1930
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0347 - root_mean_squared_error: 0.1862
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0356 - root_mean_squared_error: 0.1887
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0106 - root_mean_squared_error: 0.1032
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0225 - root_mean_squared_error: 0.1499
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0149 - root_mean_squared_error: 0.1220
# 2/2 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_73"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_73 (LSTM)              (None, 64)                17152
#
#  dense_146 (Dense)           (None, 8)                 520
#
#  dense_147 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,681
# Trainable params: 17,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.1690 - root_mean_squared_error: 0.4111
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0428 - root_mean_squared_error: 0.2069
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0603 - root_mean_squared_error: 0.2455
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0245 - root_mean_squared_error: 0.1566
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0226 - root_mean_squared_error: 0.1505
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_74"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_74 (LSTM)              (None, 64)                17152
#
#  dense_148 (Dense)           (None, 8)                 520
#
#  dense_149 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,681
# Trainable params: 17,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2123 - root_mean_squared_error: 0.4608
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1061 - root_mean_squared_error: 0.3258
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0544 - root_mean_squared_error: 0.2332
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0735 - root_mean_squared_error: 0.2711
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0652 - root_mean_squared_error: 0.2554
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0376 - root_mean_squared_error: 0.1938
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0339 - root_mean_squared_error: 0.1841
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0389 - root_mean_squared_error: 0.1972
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0316 - root_mean_squared_error: 0.1777
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0175 - root_mean_squared_error: 0.1322
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# Model: "sequential_75"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_75 (LSTM)              (None, 64)                17152
#
#  dense_150 (Dense)           (None, 8)                 520
#
#  dense_151 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,681
# Trainable params: 17,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2469 - root_mean_squared_error: 0.4969
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1320 - root_mean_squared_error: 0.3634
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0751 - root_mean_squared_error: 0.2740
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0584 - root_mean_squared_error: 0.2417
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0901 - root_mean_squared_error: 0.3002
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0619 - root_mean_squared_error: 0.2487
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0406 - root_mean_squared_error: 0.2014
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0420 - root_mean_squared_error: 0.2050
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0437 - root_mean_squared_error: 0.2090
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0294 - root_mean_squared_error: 0.1714
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# Model: "sequential_76"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_76 (LSTM)              (None, 64)                17152
#
#  dense_152 (Dense)           (None, 8)                 520
#
#  dense_153 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,681
# Trainable params: 17,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.1987 - root_mean_squared_error: 0.4457
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0690 - root_mean_squared_error: 0.2627
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0380 - root_mean_squared_error: 0.1950
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0367 - root_mean_squared_error: 0.1917
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0319 - root_mean_squared_error: 0.1786
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0326 - root_mean_squared_error: 0.1807
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0195 - root_mean_squared_error: 0.1397
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_77"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_77 (LSTM)              (None, 64)                17152
#
#  dense_154 (Dense)           (None, 8)                 520
#
#  dense_155 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,681
# Trainable params: 17,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2726 - root_mean_squared_error: 0.5221
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1316 - root_mean_squared_error: 0.3628
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0630 - root_mean_squared_error: 0.2509
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0640 - root_mean_squared_error: 0.2531
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0589 - root_mean_squared_error: 0.2427
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0327 - root_mean_squared_error: 0.1808
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0341 - root_mean_squared_error: 0.1847
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0319 - root_mean_squared_error: 0.1785
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_78"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_78 (LSTM)              (None, 64)                17408
#
#  dense_156 (Dense)           (None, 8)                 520
#
#  dense_157 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2293 - root_mean_squared_error: 0.4789
# Epoch 2/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1861 - root_mean_squared_error: 0.4314
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0740 - root_mean_squared_error: 0.2720
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0804 - root_mean_squared_error: 0.2835
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0867 - root_mean_squared_error: 0.2945
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0453 - root_mean_squared_error: 0.2129
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0428 - root_mean_squared_error: 0.2070
# Epoch 8/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0496 - root_mean_squared_error: 0.2227
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0407 - root_mean_squared_error: 0.2017
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0248 - root_mean_squared_error: 0.1576
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_79"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_79 (LSTM)              (None, 64)                17408
#
#  dense_158 (Dense)           (None, 8)                 520
#
#  dense_159 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2298 - root_mean_squared_error: 0.4794
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0646 - root_mean_squared_error: 0.2541
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0656 - root_mean_squared_error: 0.2562
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0465 - root_mean_squared_error: 0.2157
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0429 - root_mean_squared_error: 0.2072
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0317 - root_mean_squared_error: 0.1780
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0208 - root_mean_squared_error: 0.1441
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0096 - root_mean_squared_error: 0.0981
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511
# 2/2 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_80"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_80 (LSTM)              (None, 64)                17408
#
#  dense_160 (Dense)           (None, 8)                 520
#
#  dense_161 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.1715 - root_mean_squared_error: 0.4141
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0738 - root_mean_squared_error: 0.2716
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0851 - root_mean_squared_error: 0.2917
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0478 - root_mean_squared_error: 0.2187
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0353 - root_mean_squared_error: 0.1878
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0238 - root_mean_squared_error: 0.1544
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0106 - root_mean_squared_error: 0.1031
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227
# 2/2 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# Model: "sequential_81"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_81 (LSTM)              (None, 64)                17408
#
#  dense_162 (Dense)           (None, 8)                 520
#
#  dense_163 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1974 - root_mean_squared_error: 0.4443
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0666 - root_mean_squared_error: 0.2581
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0715 - root_mean_squared_error: 0.2674
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0379 - root_mean_squared_error: 0.1947
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0266 - root_mean_squared_error: 0.1629
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0261 - root_mean_squared_error: 0.1615
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0198 - root_mean_squared_error: 0.1407
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_82"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_82 (LSTM)              (None, 64)                17408
#
#  dense_164 (Dense)           (None, 8)                 520
#
#  dense_165 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1185 - root_mean_squared_error: 0.3442
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0639 - root_mean_squared_error: 0.2528
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0251 - root_mean_squared_error: 0.1584
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0123 - root_mean_squared_error: 0.1107
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0106 - root_mean_squared_error: 0.1027
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_83"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_83 (LSTM)              (None, 64)                17408
#
#  dense_166 (Dense)           (None, 8)                 520
#
#  dense_167 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.1893 - root_mean_squared_error: 0.4351
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0762 - root_mean_squared_error: 0.2761
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0404 - root_mean_squared_error: 0.2010
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0234 - root_mean_squared_error: 0.1528
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0106 - root_mean_squared_error: 0.1031
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0437 - root_mean_squared_error: 0.2090
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0164 - root_mean_squared_error: 0.1282
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_84"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_84 (LSTM)              (None, 64)                17408
#
#  dense_168 (Dense)           (None, 8)                 520
#
#  dense_169 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2302 - root_mean_squared_error: 0.4798
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1021 - root_mean_squared_error: 0.3195
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0750 - root_mean_squared_error: 0.2738
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0869 - root_mean_squared_error: 0.2948
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0548 - root_mean_squared_error: 0.2340
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0389 - root_mean_squared_error: 0.1973
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0343 - root_mean_squared_error: 0.1852
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0257 - root_mean_squared_error: 0.1603
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218
# 2/2 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_85"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_85 (LSTM)              (None, 64)                17408
#
#  dense_170 (Dense)           (None, 8)                 520
#
#  dense_171 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.1574 - root_mean_squared_error: 0.3967
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0514 - root_mean_squared_error: 0.2267
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0519 - root_mean_squared_error: 0.2277
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0112 - root_mean_squared_error: 0.1059
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0161 - root_mean_squared_error: 0.1270
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0925
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_86"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_86 (LSTM)              (None, 64)                17408
#
#  dense_172 (Dense)           (None, 8)                 520
#
#  dense_173 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1511 - root_mean_squared_error: 0.3887
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0818 - root_mean_squared_error: 0.2860
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0296 - root_mean_squared_error: 0.1721
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0412 - root_mean_squared_error: 0.2031
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0316 - root_mean_squared_error: 0.1777
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0100 - root_mean_squared_error: 0.1002
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0403 - root_mean_squared_error: 0.2009
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0149 - root_mean_squared_error: 0.1222
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0154 - root_mean_squared_error: 0.1239
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0194 - root_mean_squared_error: 0.1392
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_87"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_87 (LSTM)              (None, 64)                17408
#
#  dense_174 (Dense)           (None, 8)                 520
#
#  dense_175 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2061 - root_mean_squared_error: 0.4540
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0558 - root_mean_squared_error: 0.2363
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0667 - root_mean_squared_error: 0.2582
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0323 - root_mean_squared_error: 0.1798
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0451 - root_mean_squared_error: 0.2123
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0353 - root_mean_squared_error: 0.1880
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0242 - root_mean_squared_error: 0.1554
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0134 - root_mean_squared_error: 0.1155
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136
# 2/2 [==============================] - 1s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_88"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_88 (LSTM)              (None, 64)                17408
#
#  dense_176 (Dense)           (None, 8)                 520
#
#  dense_177 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.3008 - root_mean_squared_error: 0.5484
# Epoch 2/10
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1292 - root_mean_squared_error: 0.3595
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0760 - root_mean_squared_error: 0.2757
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0989 - root_mean_squared_error: 0.3145
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0659 - root_mean_squared_error: 0.2568
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0479 - root_mean_squared_error: 0.2189
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0536 - root_mean_squared_error: 0.2316
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0550 - root_mean_squared_error: 0.2346
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0427 - root_mean_squared_error: 0.2068
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0291 - root_mean_squared_error: 0.1707
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_89"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_89 (LSTM)              (None, 64)                17408
#
#  dense_178 (Dense)           (None, 8)                 520
#
#  dense_179 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1724 - root_mean_squared_error: 0.4153
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0620 - root_mean_squared_error: 0.2489
# Epoch 3/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0815 - root_mean_squared_error: 0.2855
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0302 - root_mean_squared_error: 0.1739
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0319 - root_mean_squared_error: 0.1787
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0193 - root_mean_squared_error: 0.1388
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0104 - root_mean_squared_error: 0.1022
# 2/2 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# Model: "sequential_90"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_90 (LSTM)              (None, 64)                17408
#
#  dense_180 (Dense)           (None, 8)                 520
#
#  dense_181 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 6ms/step - loss: 0.1607 - root_mean_squared_error: 0.4009
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0422 - root_mean_squared_error: 0.2054
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0347 - root_mean_squared_error: 0.1863
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0147 - root_mean_squared_error: 0.1213
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171
# Epoch 9/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0078 - root_mean_squared_error: 0.0883
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0139 - root_mean_squared_error: 0.1181
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_91"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_91 (LSTM)              (None, 64)                17408
#
#  dense_182 (Dense)           (None, 8)                 520
#
#  dense_183 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.1852 - root_mean_squared_error: 0.4303
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0808 - root_mean_squared_error: 0.2843
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0609 - root_mean_squared_error: 0.2468
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0408 - root_mean_squared_error: 0.2021
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0355 - root_mean_squared_error: 0.1883
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0268 - root_mean_squared_error: 0.1637
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0093 - root_mean_squared_error: 0.0964
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_92"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_92 (LSTM)              (None, 64)                17408
#  dense_184 (Dense)           (None, 8)                 520
#
#  dense_185 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 17,937
# Trainable params: 17,937
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2587 - root_mean_squared_error: 0.5086
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1695 - root_mean_squared_error: 0.4117
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0969 - root_mean_squared_error: 0.3112
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0596 - root_mean_squared_error: 0.2441
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0621 - root_mean_squared_error: 0.2492
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0409 - root_mean_squared_error: 0.2023
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0313 - root_mean_squared_error: 0.1768
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0284 - root_mean_squared_error: 0.1685
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0135 - root_mean_squared_error: 0.1160
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# Model: "sequential_93"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_93 (LSTM)              (None, 64)                17664
#
#  dense_186 (Dense)           (None, 8)                 520
#
#  dense_187 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,193
# Trainable params: 18,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1160 - root_mean_squared_error: 0.3406
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1661 - root_mean_squared_error: 0.4076
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0676 - root_mean_squared_error: 0.2600
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0560 - root_mean_squared_error: 0.2367
# Epoch 5/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0736 - root_mean_squared_error: 0.2712
# Epoch 6/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0581 - root_mean_squared_error: 0.2410
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0347 - root_mean_squared_error: 0.1863
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0367 - root_mean_squared_error: 0.1916
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0357 - root_mean_squared_error: 0.1889
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0204 - root_mean_squared_error: 0.1427
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_94"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_94 (LSTM)              (None, 64)                17664
#
#  dense_188 (Dense)           (None, 8)                 520
#
#  dense_189 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,193
# Trainable params: 18,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.1239 - root_mean_squared_error: 0.3520
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0636 - root_mean_squared_error: 0.2521
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0770 - root_mean_squared_error: 0.2775
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0570 - root_mean_squared_error: 0.2388
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0277 - root_mean_squared_error: 0.1663
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0424 - root_mean_squared_error: 0.2058
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0199 - root_mean_squared_error: 0.1412
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0252 - root_mean_squared_error: 0.1588
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_95"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_95 (LSTM)              (None, 64)                17664
#
#  dense_190 (Dense)           (None, 8)                 520
#
#  dense_191 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,193
# Trainable params: 18,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2007 - root_mean_squared_error: 0.4480
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0636 - root_mean_squared_error: 0.2523
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0677 - root_mean_squared_error: 0.2603
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0388 - root_mean_squared_error: 0.1969
# Epoch 5/10
# ...
#
#  dense_254 (Dense)           (None, 8)                 520
#
#  dense_255 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,449
# Trainable params: 18,449
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.1292 - root_mean_squared_error: 0.3595
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0866 - root_mean_squared_error: 0.2943
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0414 - root_mean_squared_error: 0.2035
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0319 - root_mean_squared_error: 0.1787
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0085 - root_mean_squared_error: 0.0921
# 2/2 [==============================] - 1s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_128"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_128 (LSTM)             (None, 64)                18176
#
#  dense_256 (Dense)           (None, 8)                 520
#
#  dense_257 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.3083 - root_mean_squared_error: 0.5552
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1071 - root_mean_squared_error: 0.3273
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0913 - root_mean_squared_error: 0.3022
# Epoch 4/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0745 - root_mean_squared_error: 0.2729
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0526 - root_mean_squared_error: 0.2293
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0495 - root_mean_squared_error: 0.2225
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0319 - root_mean_squared_error: 0.1787
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0243 - root_mean_squared_error: 0.1560
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0154 - root_mean_squared_error: 0.1242
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008
# 2/2 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_129"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_129 (LSTM)             (None, 64)                18176
#
#  dense_258 (Dense)           (None, 8)                 520
#
#  dense_259 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2283 - root_mean_squared_error: 0.4778
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0694 - root_mean_squared_error: 0.2635
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0669 - root_mean_squared_error: 0.2586
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0520 - root_mean_squared_error: 0.2281
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0439 - root_mean_squared_error: 0.2096
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0277 - root_mean_squared_error: 0.1664
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0255 - root_mean_squared_error: 0.1596
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0090 - root_mean_squared_error: 0.0949
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0318 - root_mean_squared_error: 0.1783
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_130"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_130 (LSTM)             (None, 64)                18176
#
#  dense_260 (Dense)           (None, 8)                 520
#
#  dense_261 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.1494 - root_mean_squared_error: 0.3865
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0731 - root_mean_squared_error: 0.2703
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0449 - root_mean_squared_error: 0.2120
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0724 - root_mean_squared_error: 0.2690
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0316 - root_mean_squared_error: 0.1776
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0445 - root_mean_squared_error: 0.2110
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0250 - root_mean_squared_error: 0.1581
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0218 - root_mean_squared_error: 0.1476
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0266 - root_mean_squared_error: 0.1632
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0084 - root_mean_squared_error: 0.0919
# 2/2 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# Model: "sequential_131"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_131 (LSTM)             (None, 64)                18176
#
#  dense_262 (Dense)           (None, 8)                 520
#
#  dense_263 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2062 - root_mean_squared_error: 0.4541
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0749 - root_mean_squared_error: 0.2737
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1041 - root_mean_squared_error: 0.3226
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0643 - root_mean_squared_error: 0.2536
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0605 - root_mean_squared_error: 0.2460
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0534 - root_mean_squared_error: 0.2311
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0380 - root_mean_squared_error: 0.1949
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0378 - root_mean_squared_error: 0.1945
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0230 - root_mean_squared_error: 0.1517
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# Model: "sequential_132"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_132 (LSTM)             (None, 64)                18176
#
#  dense_264 (Dense)           (None, 8)                 520
#
#  dense_265 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2307 - root_mean_squared_error: 0.4804
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0840 - root_mean_squared_error: 0.2898
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0770 - root_mean_squared_error: 0.2775
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0542 - root_mean_squared_error: 0.2328
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0604 - root_mean_squared_error: 0.2458
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0552 - root_mean_squared_error: 0.2350
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0345 - root_mean_squared_error: 0.1856
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0284 - root_mean_squared_error: 0.1686
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1340
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1386
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_133"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_133 (LSTM)             (None, 64)                18176
#
#  dense_266 (Dense)           (None, 8)                 520
#
#  dense_267 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.3075 - root_mean_squared_error: 0.5546
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0866 - root_mean_squared_error: 0.2943
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1082 - root_mean_squared_error: 0.3290
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0968 - root_mean_squared_error: 0.3110
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0527 - root_mean_squared_error: 0.2296
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0610 - root_mean_squared_error: 0.2470
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0695 - root_mean_squared_error: 0.2637
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0573 - root_mean_squared_error: 0.2394
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0394 - root_mean_squared_error: 0.1986
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0295 - root_mean_squared_error: 0.1719
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Model: "sequential_134"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_134 (LSTM)             (None, 64)                18432
#
#  dense_268 (Dense)           (None, 8)                 520
#
#  dense_269 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,961
# Trainable params: 18,961
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1558 - root_mean_squared_error: 0.3947
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0591 - root_mean_squared_error: 0.2431
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0346 - root_mean_squared_error: 0.1861
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189
# Epoch 5/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0171 - root_mean_squared_error: 0.1308
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0209 - root_mean_squared_error: 0.1447
# 2/2 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 2ms/step

# %%
len(test_results2)-1 #test data
# Out:
# 32

# %%
df_res = pd.DataFrame(finish, columns = ['combination', 'MAPE','Direction'])
df_res
# Out:
#                                 combination   MAPE  Direction
# 0                                   (Calm,)  1.333    0.43750
# 1                                   (Kind,)  1.033    0.50000
# 2                                  (Happy,)  1.822    0.43750
# 3                                  (Alert,)  1.128    0.40625
# 4                                   (Sure,)  1.549    0.43750
# ..                                      ...    ...        ...
# 58         (Calm, Kind, Happy, Sure, Vital)  4.944    0.37500
# 59         (Calm, Kind, Alert, Sure, Vital)  1.538    0.43750
# 60        (Calm, Happy, Alert, Sure, Vital)  1.495    0.46875
# 61        (Kind, Happy, Alert, Sure, Vital)  1.213    0.43750
# 62  (Calm, Kind, Happy, Alert, Sure, Vital)  1.247    0.43750
#
# [63 rows x 3 columns]

# %%
df_res.query(' Direction > 0.5').reset_index(drop=True)
# Out:
# Empty DataFrame
# Columns: [combination, MAPE, Direction]
# Index: []

# %%
df_res.query(' Direction > 0.6').reset_index(drop=True)
# Out:
# Empty DataFrame
# Columns: [combination, MAPE, Direction]
# Index: []

# %% [markdown]
# ---以下沒碰 (不知用途)

# %% [markdown]
# ### Save model-> the best one

# %%
import random
import torch

# %%
def set_random_seed(seed, deterministic=False):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    if deterministic:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %%
set_random_seed(2)

# %%
i = ['Kind', 'Happy', 'Alert', 'Vital', 'Close']

tmp = temp2[i]
NUM_FEATURE = 5
WINDOW_SIZE = 3
threshold = 41
X2, y2 = df_to_X_y2(tmp, WINDOW_SIZE)
X2.shape, y2.shape # number of data, # size of window, number of features

X_train2, y_train2 = X2[:threshold-3], y2[:threshold-3]
X_test2, y_test2 = X2[threshold:], y2[threshold:]
X_train2.shape, y_train2.shape, X_test2.shape, y_test2.shape

del model2
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, NUM_FEATURE)))
model2.add(LSTM(64))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))
model2.summary()
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])
model2.fit(X_train2, y_train2, epochs=10)

# train result
train_predictions2 = model2.predict(X_train2).flatten()
pred = mms_close.inverse_transform(train_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_train2.reshape(-1, 1))
act = act.reshape(-1,)

train_results2 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

# Test result
test_predictions2 = model2.predict(X_test2).flatten()
pred = mms_close.inverse_transform(test_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_test2.reshape(-1, 1))
act = act.reshape(-1,)

test_results2 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})
        
e1, e2 = eval(test_results2)
print(e1, e2)
# Out:
# Model: "sequential_83"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_83 (LSTM)              (None, 64)                17920
#
#  dense_166 (Dense)           (None, 8)                 520
#
#  dense_167 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,449
# Trainable params: 18,449
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 1s 4ms/step - loss: 0.3756 - root_mean_squared_error: 0.6129
# Epoch 2/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0510 - root_mean_squared_error: 0.2258
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0796 - root_mean_squared_error: 0.2821
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0418 - root_mean_squared_error: 0.2044
# Epoch 5/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0671 - root_mean_squared_error: 0.2591
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0477 - root_mean_squared_error: 0.2185
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0372 - root_mean_squared_error: 0.1929
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0391 - root_mean_squared_error: 0.1977
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0381 - root_mean_squared_error: 0.1952
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0351 - root_mean_squared_error: 0.1872
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1.565 0.8125

# %%
# model2.save('model/GPOMS_best.h5')

# %%
i = ['Kind', 'Happy', 'Alert', 'Vital', 'Close']

tmp = temp2[i]
NUM_FEATURE = 5
WINDOW_SIZE = 3
threshold = 41
X2, y2 = df_to_X_y2(tmp, WINDOW_SIZE)
X2.shape, y2.shape # number of data, # size of window, number of features

X_train2, y_train2 = X2[:threshold-3], y2[:threshold-3]
X_test2, y_test2 = X2[threshold:], y2[threshold:]
X_train2.shape, y_train2.shape, X_test2.shape, y_test2.shape

del model2
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, NUM_FEATURE)))
model2.add(LSTM(64))
model2.add(Dense(8, 'sigmoid'))
model2.add(Dense(1, 'linear'))
model2.summary()
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])
model2.fit(X_train2, y_train2, epochs=10)

# train result
train_predictions2 = model2.predict(X_train2).flatten()
pred = mms_close.inverse_transform(train_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_train2.reshape(-1, 1))
act = act.reshape(-1,)

train_results2 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

# Test result
test_predictions2 = model2.predict(X_test2).flatten()
pred = mms_close.inverse_transform(test_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_test2.reshape(-1, 1))
act = act.reshape(-1,)

test_results2 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})
        
e1, e2 = eval(test_results2)
print(e1, e2)
# Out:
# Model: "sequential_89"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_89 (LSTM)              (None, 64)                17920
#
#  dense_178 (Dense)           (None, 8)                 520
#
#  dense_179 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 18,449
# Trainable params: 18,449
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2/2 [==============================] - 1s 4ms/step - loss: 0.6743 - root_mean_squared_error: 0.8212
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2348 - root_mean_squared_error: 0.4846
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0490 - root_mean_squared_error: 0.2213
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1469 - root_mean_squared_error: 0.3833
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0803 - root_mean_squared_error: 0.2833
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0354 - root_mean_squared_error: 0.1882
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0535 - root_mean_squared_error: 0.2314
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0665 - root_mean_squared_error: 0.2580
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0581 - root_mean_squared_error: 0.2410
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0417 - root_mean_squared_error: 0.2041
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1.296 0.75

# %%
# model2.save('model/GPOMS_best(sigmoid).h5')
