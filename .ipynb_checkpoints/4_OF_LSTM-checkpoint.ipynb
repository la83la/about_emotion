# %%
import datetime
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evaluation
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
import tensorflow as tf 
from scipy import stats

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # I. Load data

# %%
OF = pd.read_pickle("Related_dataset/Opinion_Finder_result.pkl")
GPOMS = pd.read_pickle("Related_dataset/GPOMS_result.pkl")
DJIA = pd.read_pickle("Related_dataset/DJIA_filled_missing_value.pkl")

# %% [markdown]
# # II. Prepare dataset

# %%
# process OF dataframe
OF_prim = OF.drop(columns=['tweets_processed', 'tweet_size'])
OF_prim = OF_prim.reset_index()
OF_prim = OF_prim.rename({'date_prune': 'Dates'}, axis=1) 

# process GPOMS dataframe
GPOMS_pivot = GPOMS.drop(columns=['tweets_processed', 'tweet_size', 'GPOMS_preprocess_data', 'GPOMS_sum','sum_index', 'avg_index'])
GPOMS_pivot[['Calm','Kind','Happy','Alert','Sure','Vital']] = pd.DataFrame(GPOMS.GPOMS_avg.tolist(), index= GPOMS.index)
GPOMS_pivot = GPOMS_pivot.drop(['GPOMS_avg'], axis=1)
GPOMS_pivot = GPOMS_pivot.reset_index()
GPOMS_pivot = GPOMS_pivot.rename({'date_prune': 'Dates'}, axis=1) 

# process DJIA dataframe
DJIA['Dates'] = DJIA['Dates'].astype(str)

# %%
combine_df = OF_prim.merge(GPOMS_pivot, on='Dates')
combine_df = combine_df.merge(DJIA, on='Dates', how='inner')
combine_df
# Out:
#          Dates  OF_transform      Calm      Kind     Happy     Alert  \
# 0   2020-04-09     -0.380042  0.073364  0.191523 -0.115305  0.346767
# 1   2020-04-10      0.740977  0.092862  0.195467 -0.102743  0.342314
# 2   2020-04-11      0.456476  0.061887  0.278887 -0.064833  0.340592
# 3   2020-04-12      0.403397  0.082763  0.216780 -0.062001  0.329557
# 4   2020-04-13      0.144374  0.079693  0.222743 -0.091400  0.338160
# ..         ...           ...       ...       ...       ...       ...
# 72  2020-07-12      0.235669  0.078391  0.181213 -0.097056  0.369545
# 73  2020-07-13     -0.322718  0.082311  0.183053 -0.082040  0.357759
# 74  2020-07-14     -0.271762  0.098220  0.186504 -0.089044  0.359141
# 75  2020-07-15      0.002123  0.084568  0.184610 -0.079527  0.337375
# 76  2020-07-16     -0.165605  0.080464  0.185802 -0.098970  0.355024
#
#         Sure     Vital         Close
# 0   0.136158  0.155670  23719.369141
# 1   0.130042  0.118410  23555.069336
# 2   0.101464  0.160457  23472.919434
# 3   0.111304  0.079260  23431.844482
# 4   0.130949  0.137338  23390.769531
# ..       ...       ...           ...
# 72  0.147573  0.078480  26083.175781
# 73  0.154204  0.122646  26085.800781
# 74  0.150973  0.111742  26642.589844
# 75  0.146182  0.102206  26870.099609
# 76  0.149060  0.099416  26734.710938
#
# [77 rows x 9 columns]

# %% [markdown]
# # III. Build Neural Network model to predict DJIA
# input:
# 1. The past 3 days of DJIA values
# 2. Opinion Finder mood data (past 3 days)
#
# Time period (in thesis):
# > Train: 2008-2-28 ~ 2008-11-28 (10 months)
#
# > Test: 2008-12-1 ~ 2008-12-19 (19 days)
#
# Time period (in this project):
# > Train: 2020-4-9 ~ 2020-6-23 (54 days, some missing data)
#
# > Test: 2020-6-24 ~ 2022-7-16 (20 days)

# %%
threshold = 54

# %% [markdown]
# Part 1 : 只提供過去三天收盤價資訊
#
# Single variable
#
# > X[0]: [[ [1], [2], [3]]]
#
# > y[0]: [4]

# %%
def mape(actual, predict): 
    actual, predict = np.array(actual), np.array(predict)
    return np.mean(np.abs((actual - predict) / actual)) * 100

def direction(actual, predict): 
    prev_act = actual[0]
    prev_pred = predict[0]
    true = []
    res = []
    for i, j in zip(actual[1:], predict[1:]): 
        if i>=prev_act:
            true.append(1)
        else:
            true.append(-1)
        if j>=prev_pred:
            res.append(1)
        else:
            res.append(-1)
        prev_act = i
        prev_pred = j
    denorminator = len(actual) -1
    numerator = 0
    for i, j in zip(true, res):
        if i==j:
            numerator += 1
    return (numerator / denorminator)

# %%
tmp = combine_df['Close']
tmp = tmp.to_numpy().reshape(-1, 1)
scaler = MinMaxScaler()
temp = scaler.fit_transform(tmp)
temp.shape
# Out:
# (77, 1)

# %%
def df_to_X_y(df, window_size=3):
    X = []
    y = []
    for i in range(len(df)-window_size):
        row = [a for a in df[i:i+window_size]]
        X.append(row)
        label = df[i+window_size]
        y.append(label)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 3
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape # NUMBER of data, WINDOW_size, number of feature
# Out:
# ((74, 3, 1), (74, 1))

# %%
X_train1, y_train1 = X1[:threshold], y1[:threshold]
X_test1, y_test1 = X1[threshold:], y1[threshold:]
X_train1.shape, y_train1.shape, X_test1.shape, y_test1.shape
# Out:
# ((54, 3, 1), (54, 1), (20, 3, 1), (20, 1))

# %%
model1 = Sequential()
model1.add(InputLayer((WINDOW_SIZE, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])

model1.fit(X_train1, y_train1, epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2986 - root_mean_squared_error: 0.5464
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2503 - root_mean_squared_error: 0.5003
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2325 - root_mean_squared_error: 0.4822
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2111 - root_mean_squared_error: 0.4594
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0443 - root_mean_squared_error: 0.2104
# Epoch 7/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0689 - root_mean_squared_error: 0.2624
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0599 - root_mean_squared_error: 0.2448
# Epoch 9/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0338 - root_mean_squared_error: 0.1838
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0425 - root_mean_squared_error: 0.2062

# %%
def plot_modal_res(df, tp):
    plt.title(f"{tp} result")
    plt.plot(df[f'{tp} Predictions'], c='b')
    plt.plot(df['Actuals'], c='g')
    plt.legend(["Modal Predict", "Ground True"], loc ="lower right")
    plt.show()

# %%
# train result
train_predictions = model1.predict(X_train1).flatten()
pred = scaler.inverse_transform(train_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_train1)
act = act.reshape(-1,)

train_results1 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

plot_modal_res(train_results1, 'Train')
# Out:
# 2/2 [==============================] - 1s 3ms/step

# %%
# Test result
test_predictions = model1.predict(X_test1).flatten()
pred = scaler.inverse_transform(test_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_test1)
act = act.reshape(-1,)

test_results1 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})

plot_modal_res(test_results1, 'Test')
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %% [markdown]
# A little bit overfitting.
#
# ***Try to use delta***

# %%
# 加入delta
Data_new = combine_df.copy()

Data_new['tomorrow'] = Data_new['Close'].shift(-1)
Data_new.drop(Data_new.tail(1).index, inplace=True)
Data_new['delta'] = Data_new['tomorrow'] - Data_new['Close']
tmp3 = Data_new['delta']
tmp3 = tmp3.to_numpy().reshape(-1, 1)
scaler = MinMaxScaler()
temp3 = scaler.fit_transform(tmp3)

WINDOW_SIZE = 3
X3, y3 = df_to_X_y(temp3, WINDOW_SIZE)
X3.shape, y3.shape # NUMBER of data, WINDOW_size, number of feature

X_train3, y_train3 = X3[:threshold], y3[:threshold]
X_test3, y_test3 = X3[threshold:], y3[threshold:]
X_train3.shape, y_train3.shape, X_test3.shape, y_test3.shape
# Out:
# ((54, 3, 1), (54, 1), (19, 3, 1), (19, 1))

# %%
model3 = Sequential()
model3.add(InputLayer((WINDOW_SIZE, 1)))
model3.add(LSTM(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))

model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                16896
#
#  dense_2 (Dense)             (None, 8)                 520
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])

model3.fit(X_train3, y_train3, epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.4247 - root_mean_squared_error: 0.6517
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3963 - root_mean_squared_error: 0.6295
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3725 - root_mean_squared_error: 0.6104
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3492 - root_mean_squared_error: 0.5909
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3221 - root_mean_squared_error: 0.5675
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2110 - root_mean_squared_error: 0.4593
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0735 - root_mean_squared_error: 0.2711
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0335 - root_mean_squared_error: 0.1830
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0756 - root_mean_squared_error: 0.2750
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0414 - root_mean_squared_error: 0.2036

# %%
# train result
train_predictions = model3.predict(X_train3).flatten()
pred = scaler.inverse_transform(train_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_train3)
act = act.reshape(-1,)

train_results3 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

plot_modal_res(train_results3, 'Train')
# Out:
# 2/2 [==============================] - 1s 4ms/step

# %%
# Test result
test_predictions = model3.predict(X_test3).flatten()
pred = scaler.inverse_transform(test_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_test3)
act = act.reshape(-1,)

test_results3 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})

plot_modal_res(test_results3, 'Test')
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
# Part 1: past three days' DJIA data
print("MAPE:", mape(test_results3['Actuals'], test_results3['Test Predictions']).round(3), "%")
print("Directional correction rate:", "{0:.0%}".format(direction(test_results3['Actuals'], test_results3['Test Predictions'])) )
# Out:
# MAPE: 336.963 %
# Directional correction rate: 44%

# %% [markdown]
# 結果真d差

# %% [markdown]
# ***Part 2: 提供過去3天的DJIA + OF 資料***
#
# multi-variable
#
# > X[0]: [[ [1-1, 1-2, ..], [2-1, 2-2, ...], [3-1, 3-2, ...]]]
#
# > y[0]: [4]

# %%
temp2 = combine_df[['Close','OF_transform']]
mms_close = MinMaxScaler()
mms_OF = MinMaxScaler()
temp2['Close'] = mms_close.fit_transform(np.array(temp2['Close']).reshape(-1, 1))
temp2['OF_transform'] = mms_OF.fit_transform(np.array(temp2['OF_transform']).reshape(-1, 1))

# %%
def df_to_X_y2(df, window_size=3):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 3
NUM_FEATURE = 2
X2, y2 = df_to_X_y2(temp2, WINDOW_SIZE)
X2.shape, y2.shape # number of data, # size of window, number of features
# Out:
# ((74, 3, 2), (74,))

# %%
X_train2, y_train2 = X2[:threshold], y2[:threshold]
X_test2, y_test2 = X2[threshold:], y2[threshold:]
X_train2.shape, y_train2.shape, X_test2.shape, y_test2.shape
# Out:
# ((54, 3, 2), (54,), (20, 3, 2), (20,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, NUM_FEATURE)))
model2.add(LSTM(64))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 64)                17152
#
#  dense_4 (Dense)             (None, 8)                 520
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,681
# Trainable params: 17,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])
model2.fit(X_train2, y_train2, epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 9ms/step - loss: 0.1956 - root_mean_squared_error: 0.4423
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0591 - root_mean_squared_error: 0.2430
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0738 - root_mean_squared_error: 0.2717
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0332 - root_mean_squared_error: 0.1822
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0407 - root_mean_squared_error: 0.2019
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0433 - root_mean_squared_error: 0.2081
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0266 - root_mean_squared_error: 0.1630
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0216 - root_mean_squared_error: 0.1469

# %%
# train result
train_predictions2 = model2.predict(X_train2).flatten()
pred = mms_close.inverse_transform(train_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_train2.reshape(-1, 1))
act = act.reshape(-1,)

train_results2 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

plot_modal_res(train_results2, 'Train')
# Out:
# 2/2 [==============================] - 1s 5ms/step

# %%
# Test result
test_predictions2 = model2.predict(X_test2).flatten()
pred = mms_close.inverse_transform(test_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_test2.reshape(-1, 1))
act = act.reshape(-1,)

test_results2 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})

plot_modal_res(test_results2, 'Test')
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# # IV. Compute MAPE & Direction correct rate

# %%
# Part 1: past three days' DJIA data
print("MAPE:", mape(test_results1['Actuals'], test_results1['Test Predictions']).round(3), "%")
print("Directional correction rate:", "{0:.0%}".format(direction(test_results1['Actuals'], test_results1['Test Predictions'])) )
# Out:
# MAPE: 4.374 %
# Directional correction rate: 58%

# %%
plot_modal_res(test_results1, 'Test')

# %%
# Part 2: past three days' DJIA data + Opinion Finder data
print("MAPE: ", mape(test_results2['Actuals'], test_results2['Test Predictions']).round(3), "%")
print("Directional correction rate:", "{0:.0%}".format(direction(test_results2['Actuals'], test_results2['Test Predictions'])) )
# Out:
# MAPE:  0.627 %
# Directional correction rate: 74%

# %%
plot_modal_res(test_results2, 'Test')

# %% [markdown]
# reference:
#
# https://colab.research.google.com/drive/1b3CUJuDOmPmNdZFH3LQDmt5F0K3FZhqD?usp=sharing#scrollTo=FmwshpETs-jE

# %%
tmp = test_results2.copy()
tmp['pred_shift'] = tmp['Test Predictions'].shift(1)
tmp['Actuals_shift'] = tmp['Actuals'].shift(1)

tmp['pred_dire'] = tmp['Test Predictions'] - tmp['pred_shift']
tmp['pred_dire'] = tmp['pred_dire'].apply(lambda x: x>0)

tmp['act_dire'] = tmp['Actuals'] - tmp['Actuals_shift']
tmp['act_dire'] = tmp['act_dire'].apply(lambda x: x>0)
tmp
# Out:
#     Test Predictions       Actuals    pred_shift  Actuals_shift  pred_dire  \
# 0       25399.904297  25305.675781           NaN            NaN      False
# 1       25465.535156  25450.738281  25399.904297   25305.675781       True
# 2       25513.031250  25595.800781  25465.535156   25450.738281       True
# 3       25574.988281  25812.880859  25513.031250   25595.800781       True
# 4       25710.376953  25734.970703  25574.988281   25812.880859       True
# 5       25798.505859  25827.359375  25710.376953   25734.970703       True
# 6       25883.095703  26057.194336  25798.505859   25827.359375       True
# 7       26080.478516  26172.111816  25883.095703   26057.194336       True
# 8       26201.158203  26229.570557  26080.478516   26172.111816       True
# 9       26336.916016  26287.029297  26201.158203   26229.570557       True
# 10      26317.871094  25890.179687  26336.916016   26287.029297      False
# 11      26157.406250  26067.279297  26317.871094   25890.179687      False
# 12      26033.369141  25706.089844  26157.406250   26067.279297      False
# 13      25946.931641  26075.300781  26033.369141   25706.089844      False
# 14      26075.367188  26080.550781  25946.931641   26075.300781       True
# 15      26116.390625  26083.175781  26075.367188   26080.550781       True
# 16      26198.285156  26085.800781  26116.390625   26083.175781       True
# 17      26104.666016  26642.589844  26198.285156   26085.800781      False
# 18      26254.052734  26870.099609  26104.666016   26642.589844       True
# 19      26550.333984  26734.710938  26254.052734   26870.099609       True
#
#     act_dire
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10     False
# 11      True
# 12     False
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19     False

# %% [markdown]
# # Confidence Interval

# %%
MAPE = []
correction = []
NUM_FEATURE = 2

for i in range(100):
    model_k = Sequential()
    model_k.add(InputLayer((WINDOW_SIZE, NUM_FEATURE)))
    model_k.add(LSTM(64))
    model_k.add(Dense(8, 'relu'))
    model_k.add(Dense(1, 'linear'))

    model_k.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])
    model_k.fit(X_train2, y_train2, epochs=10)

    # Test result
    test_predictions2 = model_k.predict(X_test2).flatten()
    pred = mms_close.inverse_transform(test_predictions2.reshape(-1, 1))
    pred = pred.reshape(-1,)
    act = mms_close.inverse_transform(y_test2.reshape(-1, 1))
    act = act.reshape(-1,)

    test_results2 = pd.DataFrame(data={
        'Test Predictions':pred, 
        'Actuals':act})

    # Part 2: past three days' DJIA data + Opinion Finder data
    MAPE.append(mape(test_results2['Actuals'], test_results2['Test Predictions']).round(3))
    correction.append(direction(test_results2['Actuals'], test_results2['Test Predictions']))
# Out:
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.1412 - root_mean_squared_error: 0.3757
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0590 - root_mean_squared_error: 0.2430
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0379 - root_mean_squared_error: 0.1946
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0301 - root_mean_squared_error: 0.1734
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0406 - root_mean_squared_error: 0.2014
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0192 - root_mean_squared_error: 0.1384
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0213 - root_mean_squared_error: 0.1461
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297
# 1/1 [==============================] - 0s 484ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 11ms/step - loss: 0.2777 - root_mean_squared_error: 0.5269
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1008 - root_mean_squared_error: 0.3175
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0433 - root_mean_squared_error: 0.2082
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0701 - root_mean_squared_error: 0.2647
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0456 - root_mean_squared_error: 0.2135
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0278 - root_mean_squared_error: 0.1668
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0370 - root_mean_squared_error: 0.1924
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0363 - root_mean_squared_error: 0.1905
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0242 - root_mean_squared_error: 0.1556
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0186 - root_mean_squared_error: 0.1363
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001E48865AC10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 484ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2430 - root_mean_squared_error: 0.4929
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0932 - root_mean_squared_error: 0.3053
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0430 - root_mean_squared_error: 0.2075
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0676 - root_mean_squared_error: 0.2600
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0323 - root_mean_squared_error: 0.1796
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0330 - root_mean_squared_error: 0.1817
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0436 - root_mean_squared_error: 0.2089
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0356 - root_mean_squared_error: 0.1887
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0229 - root_mean_squared_error: 0.1514
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001E46C4628B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 907ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2064 - root_mean_squared_error: 0.4544
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0614 - root_mean_squared_error: 0.2478
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0633 - root_mean_squared_error: 0.2516
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0298 - root_mean_squared_error: 0.1725
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0324 - root_mean_squared_error: 0.1800
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0155 - root_mean_squared_error: 0.1247
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307
# 1/1 [==============================] - 0s 487ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 3ms/step - loss: 0.1987 - root_mean_squared_error: 0.4458
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0630 - root_mean_squared_error: 0.2509
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0859 - root_mean_squared_error: 0.2931
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0459 - root_mean_squared_error: 0.2142
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0390 - root_mean_squared_error: 0.1974
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0490 - root_mean_squared_error: 0.2213
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0382 - root_mean_squared_error: 0.1955
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0219 - root_mean_squared_error: 0.1480
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0243 - root_mean_squared_error: 0.1559
# Epoch 10/10
# 2/2 [==============================] - 0s 483ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550
# 1/1 [==============================] - 0s 479ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.3267 - root_mean_squared_error: 0.5716
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1818 - root_mean_squared_error: 0.4263
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0865 - root_mean_squared_error: 0.2941
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0526 - root_mean_squared_error: 0.2294
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0710 - root_mean_squared_error: 0.2665
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0439 - root_mean_squared_error: 0.2096
# Epoch 7/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0323 - root_mean_squared_error: 0.1798
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0425 - root_mean_squared_error: 0.2062
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0434 - root_mean_squared_error: 0.2083
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0334 - root_mean_squared_error: 0.1828
# 1/1 [==============================] - 0s 484ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 6ms/step - loss: 0.1104 - root_mean_squared_error: 0.3323
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0854 - root_mean_squared_error: 0.2923
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0362 - root_mean_squared_error: 0.1903
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0356 - root_mean_squared_error: 0.1886
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0242 - root_mean_squared_error: 0.1555
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0161 - root_mean_squared_error: 0.1267
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0137 - root_mean_squared_error: 0.1168
# 1/1 [==============================] - 0s 482ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2070 - root_mean_squared_error: 0.4550
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0595 - root_mean_squared_error: 0.2439
# Epoch 3/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0660 - root_mean_squared_error: 0.2570
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0396 - root_mean_squared_error: 0.1990
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0292 - root_mean_squared_error: 0.1709
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0338 - root_mean_squared_error: 0.1839
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0290 - root_mean_squared_error: 0.1702
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0188 - root_mean_squared_error: 0.1369
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0205 - root_mean_squared_error: 0.1431
# 1/1 [==============================] - 0s 485ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 11ms/step - loss: 0.1664 - root_mean_squared_error: 0.4080
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0802 - root_mean_squared_error: 0.2832
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0579 - root_mean_squared_error: 0.2406
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0332 - root_mean_squared_error: 0.1821
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0428 - root_mean_squared_error: 0.2068
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0291 - root_mean_squared_error: 0.1706
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0150 - root_mean_squared_error: 0.1223
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0253 - root_mean_squared_error: 0.1591
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210
# 1/1 [==============================] - 0s 483ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2004 - root_mean_squared_error: 0.4477
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0626 - root_mean_squared_error: 0.2502
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0711 - root_mean_squared_error: 0.2667
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0333 - root_mean_squared_error: 0.1824
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0328 - root_mean_squared_error: 0.1810
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0384 - root_mean_squared_error: 0.1960
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0262 - root_mean_squared_error: 0.1619
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0250 - root_mean_squared_error: 0.1581
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0159 - root_mean_squared_error: 0.1261
# 1/1 [==============================] - 0s 479ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2598 - root_mean_squared_error: 0.5097
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0632 - root_mean_squared_error: 0.2515
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0491 - root_mean_squared_error: 0.2215
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0291 - root_mean_squared_error: 0.1706
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0341 - root_mean_squared_error: 0.1846
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0228 - root_mean_squared_error: 0.1508
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0180 - root_mean_squared_error: 0.1340
# Epoch 8/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0136 - root_mean_squared_error: 0.1164
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323
# 1/1 [==============================] - 0s 484ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2526 - root_mean_squared_error: 0.5026
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0789 - root_mean_squared_error: 0.2809
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0585 - root_mean_squared_error: 0.2419
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0747 - root_mean_squared_error: 0.2733
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0329 - root_mean_squared_error: 0.1815
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0387 - root_mean_squared_error: 0.1967
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0447 - root_mean_squared_error: 0.2113
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0323 - root_mean_squared_error: 0.1797
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0179 - root_mean_squared_error: 0.1336
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0242 - root_mean_squared_error: 0.1555
# 1/1 [==============================] - 0s 485ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1608 - root_mean_squared_error: 0.4011
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0717 - root_mean_squared_error: 0.2678
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0600 - root_mean_squared_error: 0.2449
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0320 - root_mean_squared_error: 0.1790
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0417 - root_mean_squared_error: 0.2042
# Epoch 6/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0329 - root_mean_squared_error: 0.1813
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.1489
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0231 - root_mean_squared_error: 0.1519
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176
# 1/1 [==============================] - 0s 484ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.2253 - root_mean_squared_error: 0.4747
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1030 - root_mean_squared_error: 0.3209
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0533 - root_mean_squared_error: 0.2308
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0737 - root_mean_squared_error: 0.2715
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0368 - root_mean_squared_error: 0.1919
# Epoch 6/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0403 - root_mean_squared_error: 0.2007
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0445 - root_mean_squared_error: 0.2110
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0320 - root_mean_squared_error: 0.1790
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0254 - root_mean_squared_error: 0.1595
# 1/1 [==============================] - 1s 905ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2455 - root_mean_squared_error: 0.4955
# Epoch 2/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0903 - root_mean_squared_error: 0.3005
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0417 - root_mean_squared_error: 0.2043
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0695 - root_mean_squared_error: 0.2636
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0308 - root_mean_squared_error: 0.1755
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0253 - root_mean_squared_error: 0.1592
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0402 - root_mean_squared_error: 0.2006
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0335 - root_mean_squared_error: 0.1830
# Epoch 9/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330
# 1/1 [==============================] - 0s 498ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.2835 - root_mean_squared_error: 0.5324
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1542 - root_mean_squared_error: 0.3926
# Epoch 3/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0807 - root_mean_squared_error: 0.2841
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0497 - root_mean_squared_error: 0.2230
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0693 - root_mean_squared_error: 0.2633
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0455 - root_mean_squared_error: 0.2133
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0350 - root_mean_squared_error: 0.1870
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0398 - root_mean_squared_error: 0.1996
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0394 - root_mean_squared_error: 0.1985
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0296 - root_mean_squared_error: 0.1721
# 1/1 [==============================] - 0s 451ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2597 - root_mean_squared_error: 0.5096
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1103 - root_mean_squared_error: 0.3322
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0546 - root_mean_squared_error: 0.2337
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0659 - root_mean_squared_error: 0.2566
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0368 - root_mean_squared_error: 0.1918
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0282 - root_mean_squared_error: 0.1680
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0309 - root_mean_squared_error: 0.1759
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0215 - root_mean_squared_error: 0.1468
# Epoch 9/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0175 - root_mean_squared_error: 0.1324
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0205 - root_mean_squared_error: 0.1433
# 1/1 [==============================] - 0s 450ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 9ms/step - loss: 0.0984 - root_mean_squared_error: 0.3137
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0804 - root_mean_squared_error: 0.2836
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0326 - root_mean_squared_error: 0.1805
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0501 - root_mean_squared_error: 0.2238
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0317 - root_mean_squared_error: 0.1781
# Epoch 6/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0201 - root_mean_squared_error: 0.1419
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0262 - root_mean_squared_error: 0.1619
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0202 - root_mean_squared_error: 0.1420
# 1/1 [==============================] - 0s 459ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1759 - root_mean_squared_error: 0.4194
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0452 - root_mean_squared_error: 0.2127
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0529 - root_mean_squared_error: 0.2299
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0377 - root_mean_squared_error: 0.1941
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0306 - root_mean_squared_error: 0.1750
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0152 - root_mean_squared_error: 0.1233
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1340
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0131 - root_mean_squared_error: 0.1147
# 1/1 [==============================] - 0s 450ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 11ms/step - loss: 0.2463 - root_mean_squared_error: 0.4963
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1027 - root_mean_squared_error: 0.3204
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0667 - root_mean_squared_error: 0.2583
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0662 - root_mean_squared_error: 0.2573
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0425 - root_mean_squared_error: 0.2061
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0381 - root_mean_squared_error: 0.1952
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0345 - root_mean_squared_error: 0.1858
# Epoch 8/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0286 - root_mean_squared_error: 0.1692
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0251 - root_mean_squared_error: 0.1584
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0229 - root_mean_squared_error: 0.1513
# 1/1 [==============================] - 0s 473ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 9ms/step - loss: 0.2529 - root_mean_squared_error: 0.5029
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1028 - root_mean_squared_error: 0.3206
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0589 - root_mean_squared_error: 0.2426
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0651 - root_mean_squared_error: 0.2552
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0315 - root_mean_squared_error: 0.1774
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0393 - root_mean_squared_error: 0.1982
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0408 - root_mean_squared_error: 0.2021
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0251 - root_mean_squared_error: 0.1584
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0239 - root_mean_squared_error: 0.1547
# 1/1 [==============================] - 0s 495ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 9ms/step - loss: 0.2687 - root_mean_squared_error: 0.5183
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0910 - root_mean_squared_error: 0.3016
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0500 - root_mean_squared_error: 0.2235
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0743 - root_mean_squared_error: 0.2725
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0411 - root_mean_squared_error: 0.2028
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0336 - root_mean_squared_error: 0.1834
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0413 - root_mean_squared_error: 0.2031
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0392 - root_mean_squared_error: 0.1979
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0265 - root_mean_squared_error: 0.1627
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0185 - root_mean_squared_error: 0.1360
# 1/1 [==============================] - 1s 536ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2511 - root_mean_squared_error: 0.5011
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0712 - root_mean_squared_error: 0.2668
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0662 - root_mean_squared_error: 0.2573
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0242 - root_mean_squared_error: 0.1555
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0383 - root_mean_squared_error: 0.1957
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0268 - root_mean_squared_error: 0.1638
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0251 - root_mean_squared_error: 0.1583
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189
# 1/1 [==============================] - 0s 447ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 6ms/step - loss: 0.2281 - root_mean_squared_error: 0.4776
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0642 - root_mean_squared_error: 0.2533
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0693 - root_mean_squared_error: 0.2632
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0444 - root_mean_squared_error: 0.2107
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0266 - root_mean_squared_error: 0.1631
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0171 - root_mean_squared_error: 0.1309
# 1/1 [==============================] - 0s 460ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2185 - root_mean_squared_error: 0.4675
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0693 - root_mean_squared_error: 0.2632
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0652 - root_mean_squared_error: 0.2553
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0364 - root_mean_squared_error: 0.1908
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0284 - root_mean_squared_error: 0.1685
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0316 - root_mean_squared_error: 0.1778
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0191 - root_mean_squared_error: 0.1382
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0157 - root_mean_squared_error: 0.1255
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0230 - root_mean_squared_error: 0.1517
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0153 - root_mean_squared_error: 0.1238
# 1/1 [==============================] - 0s 477ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 9ms/step - loss: 0.1852 - root_mean_squared_error: 0.4303
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0550 - root_mean_squared_error: 0.2346
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0758 - root_mean_squared_error: 0.2753
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0383 - root_mean_squared_error: 0.1957
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0347 - root_mean_squared_error: 0.1862
# Epoch 6/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0401 - root_mean_squared_error: 0.2004
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0243 - root_mean_squared_error: 0.1558
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0175 - root_mean_squared_error: 0.1321
# Epoch 9/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0282 - root_mean_squared_error: 0.1678
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0179 - root_mean_squared_error: 0.1337
# 1/1 [==============================] - 0s 498ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.1461 - root_mean_squared_error: 0.3823
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0596 - root_mean_squared_error: 0.2441
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0304 - root_mean_squared_error: 0.1743
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0289 - root_mean_squared_error: 0.1699
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176
# 1/1 [==============================] - 0s 462ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 9ms/step - loss: 0.1878 - root_mean_squared_error: 0.4334
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0494 - root_mean_squared_error: 0.2223
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0662 - root_mean_squared_error: 0.2572
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0260 - root_mean_squared_error: 0.1612
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0409 - root_mean_squared_error: 0.2023
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0341 - root_mean_squared_error: 0.1846
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0161 - root_mean_squared_error: 0.1270
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0218 - root_mean_squared_error: 0.1477
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0217 - root_mean_squared_error: 0.1471
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176
# 1/1 [==============================] - 1s 502ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2547 - root_mean_squared_error: 0.5047
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1577 - root_mean_squared_error: 0.3971
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0698 - root_mean_squared_error: 0.2641
# Epoch 4/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0755 - root_mean_squared_error: 0.2747
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0406 - root_mean_squared_error: 0.2014
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0455 - root_mean_squared_error: 0.2132
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0407 - root_mean_squared_error: 0.2017
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0212 - root_mean_squared_error: 0.1456
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 2/2 [==============================] - 2s 9ms/step - loss: 0.2919 - root_mean_squared_error: 0.5402
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2308 - root_mean_squared_error: 0.4804
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1583 - root_mean_squared_error: 0.3979
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0835 - root_mean_squared_error: 0.2889
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0545 - root_mean_squared_error: 0.2334
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0823 - root_mean_squared_error: 0.2869
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0676 - root_mean_squared_error: 0.2601
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0464 - root_mean_squared_error: 0.2154
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0434 - root_mean_squared_error: 0.2082
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0504 - root_mean_squared_error: 0.2245
# 1/1 [==============================] - 0s 455ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.2497 - root_mean_squared_error: 0.4997
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0588 - root_mean_squared_error: 0.2424
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0771 - root_mean_squared_error: 0.2777
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0442 - root_mean_squared_error: 0.2103
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0336 - root_mean_squared_error: 0.1834
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0423 - root_mean_squared_error: 0.2056
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0312 - root_mean_squared_error: 0.1766
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0238 - root_mean_squared_error: 0.1544
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.2307 - root_mean_squared_error: 0.4803
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0880 - root_mean_squared_error: 0.2966
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0602 - root_mean_squared_error: 0.2454
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0594 - root_mean_squared_error: 0.2438
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0348 - root_mean_squared_error: 0.1866
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0409 - root_mean_squared_error: 0.2023
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0333 - root_mean_squared_error: 0.1824
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0209 - root_mean_squared_error: 0.1445
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0243 - root_mean_squared_error: 0.1558
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399
# 1/1 [==============================] - 0s 451ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.1479 - root_mean_squared_error: 0.3846
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0471 - root_mean_squared_error: 0.2171
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0435 - root_mean_squared_error: 0.2087
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0293 - root_mean_squared_error: 0.1711
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0327 - root_mean_squared_error: 0.1807
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0190 - root_mean_squared_error: 0.1377
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0164 - root_mean_squared_error: 0.1282
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2769 - root_mean_squared_error: 0.5262
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2447 - root_mean_squared_error: 0.4947
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2129 - root_mean_squared_error: 0.4615
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1731 - root_mean_squared_error: 0.4160
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1253 - root_mean_squared_error: 0.3540
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0683 - root_mean_squared_error: 0.2614
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0588 - root_mean_squared_error: 0.2425
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0840 - root_mean_squared_error: 0.2899
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0650 - root_mean_squared_error: 0.2549
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0450 - root_mean_squared_error: 0.2120
# 1/1 [==============================] - 0s 481ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1677 - root_mean_squared_error: 0.4096
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0522 - root_mean_squared_error: 0.2285
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0652 - root_mean_squared_error: 0.2553
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0271 - root_mean_squared_error: 0.1647
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0400 - root_mean_squared_error: 0.1999
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0338 - root_mean_squared_error: 0.1838
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0213 - root_mean_squared_error: 0.1459
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0212 - root_mean_squared_error: 0.1455
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0132 - root_mean_squared_error: 0.1148
# 1/1 [==============================] - 1s 987ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1779 - root_mean_squared_error: 0.4218
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0472 - root_mean_squared_error: 0.2172
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0621 - root_mean_squared_error: 0.2491
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0308 - root_mean_squared_error: 0.1756
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0321 - root_mean_squared_error: 0.1792
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0257 - root_mean_squared_error: 0.1604
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0210 - root_mean_squared_error: 0.1450
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0217 - root_mean_squared_error: 0.1475
# 1/1 [==============================] - 0s 475ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 7ms/step - loss: 0.2853 - root_mean_squared_error: 0.5341
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1439 - root_mean_squared_error: 0.3794
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0572 - root_mean_squared_error: 0.2392
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0672 - root_mean_squared_error: 0.2592
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0579 - root_mean_squared_error: 0.2406
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0317 - root_mean_squared_error: 0.1780
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0347 - root_mean_squared_error: 0.1863
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0428 - root_mean_squared_error: 0.2069
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0359 - root_mean_squared_error: 0.1894
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0209 - root_mean_squared_error: 0.1445
# 1/1 [==============================] - 0s 451ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 10ms/step - loss: 0.2004 - root_mean_squared_error: 0.4477
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0651 - root_mean_squared_error: 0.2551
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0807 - root_mean_squared_error: 0.2841
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0439 - root_mean_squared_error: 0.2095
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0341 - root_mean_squared_error: 0.1846
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0368 - root_mean_squared_error: 0.1919
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0181 - root_mean_squared_error: 0.1347
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0215 - root_mean_squared_error: 0.1465
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# 1/1 [==============================] - 0s 450ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2285 - root_mean_squared_error: 0.4780
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0863 - root_mean_squared_error: 0.2938
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0488 - root_mean_squared_error: 0.2209
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0637 - root_mean_squared_error: 0.2524
# Epoch 5/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0335 - root_mean_squared_error: 0.1830
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0401 - root_mean_squared_error: 0.2004
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0401 - root_mean_squared_error: 0.2003
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0294 - root_mean_squared_error: 0.1716
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0203 - root_mean_squared_error: 0.1424
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0217 - root_mean_squared_error: 0.1473
# 1/1 [==============================] - 0s 453ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.1930 - root_mean_squared_error: 0.4393
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0600 - root_mean_squared_error: 0.2450
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0409 - root_mean_squared_error: 0.2022
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0288 - root_mean_squared_error: 0.1696
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0348 - root_mean_squared_error: 0.1864
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0216 - root_mean_squared_error: 0.1471
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0209 - root_mean_squared_error: 0.1444
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0192 - root_mean_squared_error: 0.1387
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0127 - root_mean_squared_error: 0.1129
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297
# 1/1 [==============================] - 0s 447ms/step
# Epoch 1/10
# ...
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0310 - root_mean_squared_error: 0.1759
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0355 - root_mean_squared_error: 0.1884
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0383 - root_mean_squared_error: 0.1957
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0229 - root_mean_squared_error: 0.1512
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0240 - root_mean_squared_error: 0.1548
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283
# 1/1 [==============================] - 1s 863ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 14ms/step - loss: 0.2735 - root_mean_squared_error: 0.5230
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2517 - root_mean_squared_error: 0.5017
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2342 - root_mean_squared_error: 0.4839
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2202 - root_mean_squared_error: 0.4692
# Epoch 5/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2052 - root_mean_squared_error: 0.4530
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1916 - root_mean_squared_error: 0.4378
# Epoch 7/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1791 - root_mean_squared_error: 0.4232
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1678 - root_mean_squared_error: 0.4096
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1565 - root_mean_squared_error: 0.3955
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1466 - root_mean_squared_error: 0.3829
# 1/1 [==============================] - 0s 453ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1238 - root_mean_squared_error: 0.3519
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0929 - root_mean_squared_error: 0.3049
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0334 - root_mean_squared_error: 0.1828
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0383 - root_mean_squared_error: 0.1957
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0288 - root_mean_squared_error: 0.1697
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0151 - root_mean_squared_error: 0.1230
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0280 - root_mean_squared_error: 0.1672
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0181 - root_mean_squared_error: 0.1347
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0184 - root_mean_squared_error: 0.1357
# 1/1 [==============================] - 0s 466ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 17ms/step - loss: 0.2656 - root_mean_squared_error: 0.5154
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1624 - root_mean_squared_error: 0.4030
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0623 - root_mean_squared_error: 0.2495
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0702 - root_mean_squared_error: 0.2649
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0428 - root_mean_squared_error: 0.2069
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0365 - root_mean_squared_error: 0.1912
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0413 - root_mean_squared_error: 0.2033
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0276 - root_mean_squared_error: 0.1661
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0216 - root_mean_squared_error: 0.1469
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0273 - root_mean_squared_error: 0.1651
# 1/1 [==============================] - 0s 439ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 9ms/step - loss: 0.1336 - root_mean_squared_error: 0.3655
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0471 - root_mean_squared_error: 0.2171
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0385 - root_mean_squared_error: 0.1961
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0287 - root_mean_squared_error: 0.1694
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0282 - root_mean_squared_error: 0.1680
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0207 - root_mean_squared_error: 0.1438
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0138 - root_mean_squared_error: 0.1177
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312
# Epoch 10/10
# 2/2 [==============================] - 1s 524ms/step - loss: 0.0146 - root_mean_squared_error: 0.1207
# 1/1 [==============================] - 0s 455ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 14ms/step - loss: 0.2739 - root_mean_squared_error: 0.5233
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1808 - root_mean_squared_error: 0.4252
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0573 - root_mean_squared_error: 0.2395
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0857 - root_mean_squared_error: 0.2928
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0625 - root_mean_squared_error: 0.2499
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0390 - root_mean_squared_error: 0.1974
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0440 - root_mean_squared_error: 0.2096
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0445 - root_mean_squared_error: 0.2108
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0309 - root_mean_squared_error: 0.1759
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0219 - root_mean_squared_error: 0.1481
# 1/1 [==============================] - 0s 447ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 18ms/step - loss: 0.2488 - root_mean_squared_error: 0.4988
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0702 - root_mean_squared_error: 0.2649
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0677 - root_mean_squared_error: 0.2602
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0501 - root_mean_squared_error: 0.2237
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0351 - root_mean_squared_error: 0.1874
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0350 - root_mean_squared_error: 0.1870
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0293 - root_mean_squared_error: 0.1711
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0206 - root_mean_squared_error: 0.1434
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0188 - root_mean_squared_error: 0.1373
# 1/1 [==============================] - 0s 443ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 14ms/step - loss: 0.2299 - root_mean_squared_error: 0.4795
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0690 - root_mean_squared_error: 0.2627
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0545 - root_mean_squared_error: 0.2334
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0566 - root_mean_squared_error: 0.2378
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0323 - root_mean_squared_error: 0.1798
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0377 - root_mean_squared_error: 0.1942
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0347 - root_mean_squared_error: 0.1862
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0204 - root_mean_squared_error: 0.1429
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0171 - root_mean_squared_error: 0.1306
# 1/1 [==============================] - 0s 445ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1917 - root_mean_squared_error: 0.4379
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0517 - root_mean_squared_error: 0.2274
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0610 - root_mean_squared_error: 0.2470
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0373 - root_mean_squared_error: 0.1930
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0332 - root_mean_squared_error: 0.1821
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0193 - root_mean_squared_error: 0.1388
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0217 - root_mean_squared_error: 0.1473
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190
# 1/1 [==============================] - 0s 437ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2220 - root_mean_squared_error: 0.4712
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0467 - root_mean_squared_error: 0.2162
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0858 - root_mean_squared_error: 0.2929
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0353 - root_mean_squared_error: 0.1879
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0358 - root_mean_squared_error: 0.1892
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0421 - root_mean_squared_error: 0.2052
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0302 - root_mean_squared_error: 0.1738
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0178 - root_mean_squared_error: 0.1332
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0239 - root_mean_squared_error: 0.1547
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466
# 1/1 [==============================] - 0s 491ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 12ms/step - loss: 0.2137 - root_mean_squared_error: 0.4623
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0424 - root_mean_squared_error: 0.2058
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0766 - root_mean_squared_error: 0.2768
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0368 - root_mean_squared_error: 0.1917
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0367 - root_mean_squared_error: 0.1916
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0437 - root_mean_squared_error: 0.2090
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0271 - root_mean_squared_error: 0.1646
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0190 - root_mean_squared_error: 0.1377
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0242 - root_mean_squared_error: 0.1556
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349
# 1/1 [==============================] - 0s 467ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 10ms/step - loss: 0.2472 - root_mean_squared_error: 0.4972
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1056 - root_mean_squared_error: 0.3250
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0650 - root_mean_squared_error: 0.2549
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0731 - root_mean_squared_error: 0.2704
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0405 - root_mean_squared_error: 0.2012
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0392 - root_mean_squared_error: 0.1980
# Epoch 7/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0361 - root_mean_squared_error: 0.1899
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0202 - root_mean_squared_error: 0.1422
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0210 - root_mean_squared_error: 0.1449
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0221 - root_mean_squared_error: 0.1485
# 1/1 [==============================] - 0s 443ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 17ms/step - loss: 0.2668 - root_mean_squared_error: 0.5165
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0788 - root_mean_squared_error: 0.2807
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0593 - root_mean_squared_error: 0.2434
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0653 - root_mean_squared_error: 0.2554
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0307 - root_mean_squared_error: 0.1753
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0398 - root_mean_squared_error: 0.1996
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0471 - root_mean_squared_error: 0.2169
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0324 - root_mean_squared_error: 0.1800
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0211 - root_mean_squared_error: 0.1453
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0246 - root_mean_squared_error: 0.1569
# 1/1 [==============================] - 0s 452ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 14ms/step - loss: 0.2079 - root_mean_squared_error: 0.4559
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0550 - root_mean_squared_error: 0.2346
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0668 - root_mean_squared_error: 0.2584
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0382 - root_mean_squared_error: 0.1953
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0331 - root_mean_squared_error: 0.1820
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0334 - root_mean_squared_error: 0.1828
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# 1/1 [==============================] - 1s 863ms/step

# %%
df_res = pd.DataFrame(
    {'MAPE': MAPE,
     'Direction': correction})
df_res.describe()
# Out:
#              MAPE   Direction
# count  100.000000  100.000000
# mean     1.504840    0.571053
# std      1.022817    0.108503
# min      0.618000    0.368421
# 25%      0.842750    0.473684
# 50%      1.204500    0.578947
# 75%      1.876750    0.631579
# max      8.216000    0.789474

# %%
plt.title("MAPE")
plt.plot(df_res['MAPE'])
plt.show()

# %%
plt.title("Direction")
plt.plot(df_res['Direction'])
plt.show()
