# %%
import datetime
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evaluation
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
import tensorflow as tf 
from scipy import stats

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # I. Load data

# %%
OF = pd.read_pickle("Related_dataset/Opinion_Finder_result.pkl")
GPOMS = pd.read_pickle("Related_dataset/GPOMS_result.pkl")
DJIA = pd.read_pickle("Related_dataset/DJIA_filled_missing_value.pkl")

# %% [markdown]
# # II. Prepare dataset

# %%
# process OF dataframe
OF_prim = OF.drop(columns=['tweets_processed', 'tweet_size'])
OF_prim = OF_prim.reset_index()
OF_prim = OF_prim.rename({'date_prune': 'Dates'}, axis=1) 

# process GPOMS dataframe
GPOMS_pivot = GPOMS.drop(columns=['tweets_processed', 'tweet_size', 'GPOMS_preprocess_data', 'GPOMS_sum','sum_index', 'avg_index'])
GPOMS_pivot[['Calm','Kind','Happy','Alert','Sure','Vital']] = pd.DataFrame(GPOMS.GPOMS_avg.tolist(), index= GPOMS.index)
GPOMS_pivot = GPOMS_pivot.drop(['GPOMS_avg'], axis=1)
GPOMS_pivot = GPOMS_pivot.reset_index()
GPOMS_pivot = GPOMS_pivot.rename({'date_prune': 'Dates'}, axis=1) 

# process DJIA dataframe
DJIA['Dates'] = DJIA['Dates'].astype(str)

# %%
combine_df = OF_prim.merge(GPOMS_pivot, on='Dates')
combine_df = combine_df.merge(DJIA, on='Dates', how='inner')
combine_df
# Out:
#          Dates  OF_transform      Calm      Kind     Happy     Alert  \
# 0   2020-04-09     -0.380042  0.073364  0.191523 -0.115305  0.346767
# 1   2020-04-10      0.740977  0.092862  0.195467 -0.102743  0.342314
# 2   2020-04-11      0.456476  0.061887  0.278887 -0.064833  0.340592
# 3   2020-04-12      0.403397  0.082763  0.216780 -0.062001  0.329557
# 4   2020-04-13      0.144374  0.079693  0.222743 -0.091400  0.338160
# ..         ...           ...       ...       ...       ...       ...
# 72  2020-07-12      0.235669  0.078391  0.181213 -0.097056  0.369545
# 73  2020-07-13     -0.322718  0.082311  0.183053 -0.082040  0.357759
# 74  2020-07-14     -0.271762  0.098220  0.186504 -0.089044  0.359141
# 75  2020-07-15      0.002123  0.084568  0.184610 -0.079527  0.337375
# 76  2020-07-16     -0.165605  0.080464  0.185802 -0.098970  0.355024
#
#         Sure     Vital         Close
# 0   0.136158  0.155670  23719.369141
# 1   0.130042  0.118410  23555.069336
# 2   0.101464  0.160457  23472.919434
# 3   0.111304  0.079260  23431.844482
# 4   0.130949  0.137338  23390.769531
# ..       ...       ...           ...
# 72  0.147573  0.078480  26083.175781
# 73  0.154204  0.122646  26085.800781
# 74  0.150973  0.111742  26642.589844
# 75  0.146182  0.102206  26870.099609
# 76  0.149060  0.099416  26734.710938
#
# [77 rows x 9 columns]

# %% [markdown]
# # III. Build Neural Network model to predict DJIA
# input:
# 1. The past 3 days of DJIA values
# 2. Opinion Finder mood data (past 3 days)
#
# Time period (in thesis):
# > Train: 2008-2-28 ~ 2008-11-28 (10 months)
#
# > Test: 2008-12-1 ~ 2008-12-19 (19 days)
#
# Time period (in this project):
# > Train: 2020-4-9 ~ 2020-6-23 (54 days, some missing data)
#
# > Test: 2020-6-24 ~ 2022-7-16 (20 days)

# %%
threshold = 54

# %% [markdown]
# Part 1 : 只提供過去三天收盤價資訊
#
# Single variable
#
# > X[0]: [[ [1], [2], [3]]]
#
# > y[0]: [4]

# %%
def mape(actual, predict): 
    actual, predict = np.array(actual), np.array(predict)
    return np.mean(np.abs((actual - predict) / actual)) * 100

def direction(actual, predict): 
    prev_act = actual[0]
    prev_pred = predict[0]
    true = []
    res = []
    for i, j in zip(actual[1:], predict[1:]): 
        if i>=prev_act:
            true.append(1)
        else:
            true.append(-1)
        if j>=prev_pred:
            res.append(1)
        else:
            res.append(-1)
        prev_act = i
        prev_pred = j
    denorminator = len(actual) -1
    numerator = 0
    for i, j in zip(true, res):
        if i==j:
            numerator += 1
    return (numerator / denorminator)

# %%
tmp = combine_df['Close']
tmp = tmp.to_numpy().reshape(-1, 1)
scaler = MinMaxScaler()
temp = scaler.fit_transform(tmp)
temp.shape
# Out:
# (77, 1)

# %%
def df_to_X_y(df, window_size=3):
    X = []
    y = []
    for i in range(len(df)-window_size):
        row = [a for a in df[i:i+window_size]]
        X.append(row)
        label = df[i+window_size]
        y.append(label)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 3
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape # NUMBER of data, WINDOW_size, number of feature
# Out:
# ((74, 3, 1), (74, 1))

# %%
X_train1, y_train1 = X1[:threshold], y1[:threshold]
X_test1, y_test1 = X1[threshold:], y1[threshold:]
X_train1.shape, y_train1.shape, X_test1.shape, y_test1.shape
# Out:
# ((54, 3, 1), (54, 1), (20, 3, 1), (20, 1))

# %%
model1 = Sequential()
model1.add(InputLayer((WINDOW_SIZE, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])

model1.fit(X_train1, y_train1, epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2223 - root_mean_squared_error: 0.4715
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0818 - root_mean_squared_error: 0.2859
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0449 - root_mean_squared_error: 0.2118
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0629 - root_mean_squared_error: 0.2508
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0275 - root_mean_squared_error: 0.1659
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0282 - root_mean_squared_error: 0.1681
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0365 - root_mean_squared_error: 0.1911
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0320 - root_mean_squared_error: 0.1788
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0216 - root_mean_squared_error: 0.1468
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0172 - root_mean_squared_error: 0.1310

# %%
def plot_modal_res(df, tp):
    plt.title(f"{tp} result")
    plt.plot(df[f'{tp} Predictions'], c='b')
    plt.plot(df['Actuals'], c='g')
    plt.legend(["Modal Predict", "Ground True"], loc ="lower right")
    plt.show()

# %%
# train result
train_predictions = model1.predict(X_train1).flatten()
pred = scaler.inverse_transform(train_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_train1)
act = act.reshape(-1,)

train_results1 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

plot_modal_res(train_results1, 'Train')
# Out:
# 2/2 [==============================] - 1s 4ms/step

# %%
# Test result
test_predictions = model1.predict(X_test1).flatten()
pred = scaler.inverse_transform(test_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_test1)
act = act.reshape(-1,)

test_results1 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})

plot_modal_res(test_results1, 'Test')
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %% [markdown]
# A little bit overfitting.
#
# ***Try to use delta***

# %%
# 加入delta
Data_new = combine_df.copy()

Data_new['tomorrow'] = Data_new['Close'].shift(-1)
Data_new.drop(Data_new.tail(1).index, inplace=True)
Data_new['delta'] = Data_new['tomorrow'] - Data_new['Close']
tmp3 = Data_new['delta']
tmp3 = tmp3.to_numpy().reshape(-1, 1)
scaler = MinMaxScaler()
temp3 = scaler.fit_transform(tmp3)

WINDOW_SIZE = 3
X3, y3 = df_to_X_y(temp3, WINDOW_SIZE)
X3.shape, y3.shape # NUMBER of data, WINDOW_size, number of feature

X_train3, y_train3 = X3[:threshold], y3[:threshold]
X_test3, y_test3 = X3[threshold:], y3[threshold:]
X_train3.shape, y_train3.shape, X_test3.shape, y_test3.shape
# Out:
# ((54, 3, 1), (54, 1), (19, 3, 1), (19, 1))

# %%
model3 = Sequential()
model3.add(InputLayer((WINDOW_SIZE, 1)))
model3.add(LSTM(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))

model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                16896
#
#  dense_2 (Dense)             (None, 8)                 520
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])

model3.fit(X_train3, y_train3, epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.4000 - root_mean_squared_error: 0.6325
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2198 - root_mean_squared_error: 0.4689
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0734 - root_mean_squared_error: 0.2710
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0433 - root_mean_squared_error: 0.2080
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0872 - root_mean_squared_error: 0.2954
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0340 - root_mean_squared_error: 0.1843
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0276 - root_mean_squared_error: 0.1662
# Epoch 8/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0452 - root_mean_squared_error: 0.2126
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0480 - root_mean_squared_error: 0.2191
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0374 - root_mean_squared_error: 0.1935

# %%
# train result
train_predictions = model3.predict(X_train3).flatten()
pred = scaler.inverse_transform(train_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_train3)
act = act.reshape(-1,)

train_results3 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

plot_modal_res(train_results3, 'Train')
# Out:
# 2/2 [==============================] - 1s 2ms/step

# %%
# Test result
test_predictions = model3.predict(X_test3).flatten()
pred = scaler.inverse_transform(test_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_test3)
act = act.reshape(-1,)

test_results3 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})

plot_modal_res(test_results3, 'Test')
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
# Part 1: past three days' DJIA data
print("MAPE:", mape(test_results3['Actuals'], test_results3['Test Predictions']).round(3), "%")
print("Directional correction rate:", "{0:.0%}".format(direction(test_results3['Actuals'], test_results3['Test Predictions'])) )
# Out:
# MAPE: 837.669 %
# Directional correction rate: 39%

# %% [markdown]
# 結果真d差

# %% [markdown]
# ***Part 2: 提供過去3天的DJIA + OF 資料***
#
# multi-variable
#
# > X[0]: [[ [1-1, 1-2, ..], [2-1, 2-2, ...], [3-1, 3-2, ...]]]
#
# > y[0]: [4]

# %%
temp2 = combine_df[['Close','OF_transform']]
mms_close = MinMaxScaler()
mms_OF = MinMaxScaler()
temp2['Close'] = mms_close.fit_transform(np.array(temp2['Close']).reshape(-1, 1))
temp2['OF_transform'] = mms_OF.fit_transform(np.array(temp2['OF_transform']).reshape(-1, 1))

# %%
def df_to_X_y2(df, window_size=3):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 3
NUM_FEATURE = 2
X2, y2 = df_to_X_y2(temp2, WINDOW_SIZE)
X2.shape, y2.shape # number of data, # size of window, number of features
# Out:
# ((74, 3, 2), (74,))

# %%
X_train2, y_train2 = X2[:threshold], y2[:threshold]
X_test2, y_test2 = X2[threshold:], y2[threshold:]
X_train2.shape, y_train2.shape, X_test2.shape, y_test2.shape
# Out:
# ((54, 3, 2), (54,), (20, 3, 2), (20,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, NUM_FEATURE)))
model2.add(LSTM(64))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 64)                17152
#
#  dense_4 (Dense)             (None, 8)                 520
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,681
# Trainable params: 17,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])
model2.fit(X_train2, y_train2, epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2474 - root_mean_squared_error: 0.4974
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0777 - root_mean_squared_error: 0.2788
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0685 - root_mean_squared_error: 0.2617
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0467 - root_mean_squared_error: 0.2161
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0336 - root_mean_squared_error: 0.1833
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0430 - root_mean_squared_error: 0.2073
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0272 - root_mean_squared_error: 0.1650
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0180 - root_mean_squared_error: 0.1340
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0254 - root_mean_squared_error: 0.1594
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0173 - root_mean_squared_error: 0.1317

# %%
# train result
train_predictions2 = model2.predict(X_train2).flatten()
pred = mms_close.inverse_transform(train_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_train2.reshape(-1, 1))
act = act.reshape(-1,)

train_results2 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

plot_modal_res(train_results2, 'Train')
# Out:
# 2/2 [==============================] - 1s 3ms/step

# %%
# Test result
test_predictions2 = model2.predict(X_test2).flatten()
pred = mms_close.inverse_transform(test_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_test2.reshape(-1, 1))
act = act.reshape(-1,)

test_results2 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})

plot_modal_res(test_results2, 'Test')
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %% [markdown]
# # IV. Compute MAPE & Direction correct rate

# %%
# Part 1: past three days' DJIA data
print("MAPE:", mape(test_results1['Actuals'], test_results1['Test Predictions']).round(3), "%")
print("Directional correction rate:", "{0:.0%}".format(direction(test_results1['Actuals'], test_results1['Test Predictions'])) )
# Out:
# MAPE: 0.831 %
# Directional correction rate: 58%

# %%
plot_modal_res(test_results1, 'Test')

# %%
# Part 2: past three days' DJIA data + Opinion Finder data
print("MAPE: ", mape(test_results2['Actuals'], test_results2['Test Predictions']).round(3), "%")
print("Directional correction rate:", "{0:.0%}".format(direction(test_results2['Actuals'], test_results2['Test Predictions'])) )
# Out:
# MAPE:  1.366 %
# Directional correction rate: 58%

# %%
plot_modal_res(test_results2, 'Test')

# %% [markdown]
# reference:
#
# https://colab.research.google.com/drive/1b3CUJuDOmPmNdZFH3LQDmt5F0K3FZhqD?usp=sharing#scrollTo=FmwshpETs-jE

# %%
tmp = test_results2.copy()
tmp['pred_shift'] = tmp['Test Predictions'].shift(1)
tmp['Actuals_shift'] = tmp['Actuals'].shift(1)

tmp['pred_dire'] = tmp['Test Predictions'] - tmp['pred_shift']
tmp['pred_dire'] = tmp['pred_dire'].apply(lambda x: x>0)

tmp['act_dire'] = tmp['Actuals'] - tmp['Actuals_shift']
tmp['act_dire'] = tmp['act_dire'].apply(lambda x: x>0)
tmp
# Out:
#     Test Predictions       Actuals    pred_shift  Actuals_shift  pred_dire  \
# 0       25243.439453  25305.675781           NaN            NaN      False
# 1       25309.451172  25450.738281  25243.439453   25305.675781       True
# 2       25272.220703  25595.800781  25309.451172   25450.738281      False
# 3       25273.470703  25812.880859  25272.220703   25595.800781       True
# 4       25401.628906  25734.970703  25273.470703   25812.880859       True
# 5       25550.519531  25827.359375  25401.628906   25734.970703       True
# 6       25616.292969  26057.194336  25550.519531   25827.359375       True
# 7       25749.031250  26172.111816  25616.292969   26057.194336       True
# 8       25808.433594  26229.570557  25749.031250   26172.111816       True
# 9       25881.029297  26287.029297  25808.433594   26229.570557       True
# 10      25909.554688  25890.179687  25881.029297   26287.029297       True
# 11      25808.568359  26067.279297  25909.554688   25890.179687      False
# 12      25790.916016  25706.089844  25808.568359   26067.279297      False
# 13      25724.824219  26075.300781  25790.916016   25706.089844      False
# 14      25827.796875  26080.550781  25724.824219   26075.300781       True
# 15      25768.332031  26083.175781  25827.796875   26080.550781      False
# 16      25839.703125  26085.800781  25768.332031   26083.175781       True
# 17      25771.652344  26642.589844  25839.703125   26085.800781      False
# 18      25946.746094  26870.099609  25771.652344   26642.589844       True
# 19      26262.908203  26734.710938  25946.746094   26870.099609       True
#
#     act_dire
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10     False
# 11      True
# 12     False
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19     False

# %% [markdown]
# # Confidence Interval

# %%
MAPE = []
correction = []
NUM_FEATURE = 2

for i in range(100):
    model_k = Sequential()
    model_k.add(InputLayer((WINDOW_SIZE, NUM_FEATURE)))
    model_k.add(LSTM(64))
    model_k.add(Dense(8, 'relu'))
    model_k.add(Dense(1, 'linear'))

    model_k.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])
    model_k.fit(X_train2, y_train2, epochs=10)

    # Test result
    test_predictions2 = model_k.predict(X_test2).flatten()
    pred = mms_close.inverse_transform(test_predictions2.reshape(-1, 1))
    pred = pred.reshape(-1,)
    act = mms_close.inverse_transform(y_test2.reshape(-1, 1))
    act = act.reshape(-1,)

    test_results2 = pd.DataFrame(data={
        'Test Predictions':pred, 
        'Actuals':act})

    # Part 2: past three days' DJIA data + Opinion Finder data
    MAPE.append(mape(test_results2['Actuals'], test_results2['Test Predictions']).round(3))
    correction.append(direction(test_results2['Actuals'], test_results2['Test Predictions']))
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1776 - root_mean_squared_error: 0.4215
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0623 - root_mean_squared_error: 0.2496
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0682 - root_mean_squared_error: 0.2611
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0292 - root_mean_squared_error: 0.1709
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0403 - root_mean_squared_error: 0.2007
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0399 - root_mean_squared_error: 0.1996
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0217 - root_mean_squared_error: 0.1472
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1384
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0256 - root_mean_squared_error: 0.1599
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0169 - root_mean_squared_error: 0.1300
# WARNING:tensorflow:6 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001CC01F75940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 532ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1693 - root_mean_squared_error: 0.4115
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0524 - root_mean_squared_error: 0.2290
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0328 - root_mean_squared_error: 0.1812
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0386 - root_mean_squared_error: 0.1965
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326
# Epoch 6/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0299 - root_mean_squared_error: 0.1730
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0284 - root_mean_squared_error: 0.1685
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0152 - root_mean_squared_error: 0.1235
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0221 - root_mean_squared_error: 0.1487
# 1/1 [==============================] - 1s 565ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2575 - root_mean_squared_error: 0.5074
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0910 - root_mean_squared_error: 0.3016
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0499 - root_mean_squared_error: 0.2233
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0645 - root_mean_squared_error: 0.2539
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0381 - root_mean_squared_error: 0.1953
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0326 - root_mean_squared_error: 0.1805
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0372 - root_mean_squared_error: 0.1928
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0286 - root_mean_squared_error: 0.1690
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0198 - root_mean_squared_error: 0.1407
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0212 - root_mean_squared_error: 0.1456
# 1/1 [==============================] - 0s 476ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2702 - root_mean_squared_error: 0.5199
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1648 - root_mean_squared_error: 0.4060
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0629 - root_mean_squared_error: 0.2507
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0741 - root_mean_squared_error: 0.2722
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0620 - root_mean_squared_error: 0.2489
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0349 - root_mean_squared_error: 0.1867
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0379 - root_mean_squared_error: 0.1946
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0390 - root_mean_squared_error: 0.1975
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0311 - root_mean_squared_error: 0.1764
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0223 - root_mean_squared_error: 0.1494
# 1/1 [==============================] - 0s 474ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2331 - root_mean_squared_error: 0.4828
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0895 - root_mean_squared_error: 0.2992
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0556 - root_mean_squared_error: 0.2357
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0714 - root_mean_squared_error: 0.2672
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0363 - root_mean_squared_error: 0.1905
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0363 - root_mean_squared_error: 0.1905
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0415 - root_mean_squared_error: 0.2038
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0299 - root_mean_squared_error: 0.1730
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0186 - root_mean_squared_error: 0.1362
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579
# 1/1 [==============================] - 0s 476ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2693 - root_mean_squared_error: 0.5189
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2024 - root_mean_squared_error: 0.4499
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1205 - root_mean_squared_error: 0.3471
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0559 - root_mean_squared_error: 0.2364
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0680 - root_mean_squared_error: 0.2607
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0607 - root_mean_squared_error: 0.2464
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0371 - root_mean_squared_error: 0.1927
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0465 - root_mean_squared_error: 0.2157
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0483 - root_mean_squared_error: 0.2198
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0417 - root_mean_squared_error: 0.2042
# 1/1 [==============================] - 0s 472ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2451 - root_mean_squared_error: 0.4951
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0689 - root_mean_squared_error: 0.2625
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0687 - root_mean_squared_error: 0.2621
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0494 - root_mean_squared_error: 0.2223
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0306 - root_mean_squared_error: 0.1750
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0387 - root_mean_squared_error: 0.1967
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0256 - root_mean_squared_error: 0.1601
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0182 - root_mean_squared_error: 0.1347
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0206 - root_mean_squared_error: 0.1435
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208
# 1/1 [==============================] - 1s 948ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2805 - root_mean_squared_error: 0.5297
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2152 - root_mean_squared_error: 0.4639
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1569 - root_mean_squared_error: 0.3961
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0756 - root_mean_squared_error: 0.2750
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0475 - root_mean_squared_error: 0.2180
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0809 - root_mean_squared_error: 0.2844
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0605 - root_mean_squared_error: 0.2460
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0392 - root_mean_squared_error: 0.1979
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0421 - root_mean_squared_error: 0.2053
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0489 - root_mean_squared_error: 0.2212
# 1/1 [==============================] - 0s 481ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2460 - root_mean_squared_error: 0.4959
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1045 - root_mean_squared_error: 0.3232
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0642 - root_mean_squared_error: 0.2535
# Epoch 4/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0768 - root_mean_squared_error: 0.2771
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0429 - root_mean_squared_error: 0.2071
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0419 - root_mean_squared_error: 0.2046
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0453 - root_mean_squared_error: 0.2129
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0356 - root_mean_squared_error: 0.1888
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0252 - root_mean_squared_error: 0.1586
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557
# 1/1 [==============================] - 1s 611ms/step
# Epoch 1/10
# 2/2 [==============================] - 4s 6ms/step - loss: 0.1748 - root_mean_squared_error: 0.4181
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0395 - root_mean_squared_error: 0.1987
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0454 - root_mean_squared_error: 0.2132
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0280 - root_mean_squared_error: 0.1673
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0277 - root_mean_squared_error: 0.1663
# Epoch 6/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0194 - root_mean_squared_error: 0.1393
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157
# 1/1 [==============================] - 1s 653ms/step
# Epoch 1/10
# 2/2 [==============================] - 4s 5ms/step - loss: 0.2679 - root_mean_squared_error: 0.5176
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1713 - root_mean_squared_error: 0.4139
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0687 - root_mean_squared_error: 0.2622
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0610 - root_mean_squared_error: 0.2471
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0663 - root_mean_squared_error: 0.2574
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0367 - root_mean_squared_error: 0.1915
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0405 - root_mean_squared_error: 0.2013
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0467 - root_mean_squared_error: 0.2162
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0392 - root_mean_squared_error: 0.1981
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0253 - root_mean_squared_error: 0.1592
# 1/1 [==============================] - 1s 670ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2626 - root_mean_squared_error: 0.5124
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1150 - root_mean_squared_error: 0.3391
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0564 - root_mean_squared_error: 0.2375
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0370 - root_mean_squared_error: 0.1925
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0397 - root_mean_squared_error: 0.1992
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0206 - root_mean_squared_error: 0.1437
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0231 - root_mean_squared_error: 0.1520
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0174 - root_mean_squared_error: 0.1320
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0202 - root_mean_squared_error: 0.1423
# 1/1 [==============================] - 1s 555ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2501 - root_mean_squared_error: 0.5001
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0759 - root_mean_squared_error: 0.2755
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0768 - root_mean_squared_error: 0.2772
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0532 - root_mean_squared_error: 0.2308
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0375 - root_mean_squared_error: 0.1937
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0439 - root_mean_squared_error: 0.2095
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0287 - root_mean_squared_error: 0.1696
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0210 - root_mean_squared_error: 0.1448
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0237 - root_mean_squared_error: 0.1541
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0149 - root_mean_squared_error: 0.1220
# 1/1 [==============================] - 1s 501ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2468 - root_mean_squared_error: 0.4968
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1407 - root_mean_squared_error: 0.3751
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0478 - root_mean_squared_error: 0.2186
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0693 - root_mean_squared_error: 0.2632
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0554 - root_mean_squared_error: 0.2353
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0328 - root_mean_squared_error: 0.1811
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0383 - root_mean_squared_error: 0.1957
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0408 - root_mean_squared_error: 0.2020
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0308 - root_mean_squared_error: 0.1754
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0209 - root_mean_squared_error: 0.1447
# 1/1 [==============================] - 1s 535ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2251 - root_mean_squared_error: 0.4744
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0643 - root_mean_squared_error: 0.2535
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0758 - root_mean_squared_error: 0.2753
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0443 - root_mean_squared_error: 0.2106
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0308 - root_mean_squared_error: 0.1756
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0432 - root_mean_squared_error: 0.2078
# Epoch 7/10
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0370 - root_mean_squared_error: 0.1924
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0209 - root_mean_squared_error: 0.1447
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0264 - root_mean_squared_error: 0.1625
# 1/1 [==============================] - 1s 513ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2239 - root_mean_squared_error: 0.4732
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0488 - root_mean_squared_error: 0.2209
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0790 - root_mean_squared_error: 0.2812
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0298 - root_mean_squared_error: 0.1725
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0413 - root_mean_squared_error: 0.2032
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0388 - root_mean_squared_error: 0.1969
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0194 - root_mean_squared_error: 0.1392
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0251 - root_mean_squared_error: 0.1584
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121
# 1/1 [==============================] - 1s 550ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2635 - root_mean_squared_error: 0.5133
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1717 - root_mean_squared_error: 0.4144
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0885 - root_mean_squared_error: 0.2974
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0643 - root_mean_squared_error: 0.2535
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0750 - root_mean_squared_error: 0.2739
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0398 - root_mean_squared_error: 0.1996
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0359 - root_mean_squared_error: 0.1894
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0334 - root_mean_squared_error: 0.1829
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0254 - root_mean_squared_error: 0.1594
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0210 - root_mean_squared_error: 0.1451
# 1/1 [==============================] - 1s 546ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2870 - root_mean_squared_error: 0.5357
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0967 - root_mean_squared_error: 0.3110
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0497 - root_mean_squared_error: 0.2229
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0696 - root_mean_squared_error: 0.2639
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0285 - root_mean_squared_error: 0.1687
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0419 - root_mean_squared_error: 0.2048
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0477 - root_mean_squared_error: 0.2184
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0299 - root_mean_squared_error: 0.1729
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0297 - root_mean_squared_error: 0.1725
# 1/1 [==============================] - 0s 497ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1919 - root_mean_squared_error: 0.4381
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0525 - root_mean_squared_error: 0.2291
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0616 - root_mean_squared_error: 0.2482
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0300 - root_mean_squared_error: 0.1733
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0372 - root_mean_squared_error: 0.1928
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0275 - root_mean_squared_error: 0.1658
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0172 - root_mean_squared_error: 0.1310
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0231 - root_mean_squared_error: 0.1520
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0207 - root_mean_squared_error: 0.1440
# 1/1 [==============================] - 1s 528ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2514 - root_mean_squared_error: 0.5014
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0399 - root_mean_squared_error: 0.1997
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0609 - root_mean_squared_error: 0.2467
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0306 - root_mean_squared_error: 0.1749
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0385 - root_mean_squared_error: 0.1962
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0253 - root_mean_squared_error: 0.1589
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0218 - root_mean_squared_error: 0.1476
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0147 - root_mean_squared_error: 0.1213
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197
# 1/1 [==============================] - 1s 581ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2124 - root_mean_squared_error: 0.4609
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0448 - root_mean_squared_error: 0.2117
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0637 - root_mean_squared_error: 0.2524
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0280 - root_mean_squared_error: 0.1672
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0448 - root_mean_squared_error: 0.2117
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0322 - root_mean_squared_error: 0.1796
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0182 - root_mean_squared_error: 0.1350
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0247 - root_mean_squared_error: 0.1570
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0192 - root_mean_squared_error: 0.1385
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147
# 1/1 [==============================] - 1s 566ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2220 - root_mean_squared_error: 0.4711
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0592 - root_mean_squared_error: 0.2433
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0640 - root_mean_squared_error: 0.2529
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0308 - root_mean_squared_error: 0.1754
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0312 - root_mean_squared_error: 0.1767
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0357 - root_mean_squared_error: 0.1889
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0175 - root_mean_squared_error: 0.1324
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0197 - root_mean_squared_error: 0.1404
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0133 - root_mean_squared_error: 0.1151
# 1/1 [==============================] - 1s 501ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2145 - root_mean_squared_error: 0.4632
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0556 - root_mean_squared_error: 0.2358
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0726 - root_mean_squared_error: 0.2694
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0433 - root_mean_squared_error: 0.2080
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0322 - root_mean_squared_error: 0.1795
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0346 - root_mean_squared_error: 0.1859
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0201 - root_mean_squared_error: 0.1419
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0159 - root_mean_squared_error: 0.1262
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0148 - root_mean_squared_error: 0.1217
# 1/1 [==============================] - 1s 507ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2277 - root_mean_squared_error: 0.4772
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0921 - root_mean_squared_error: 0.3035
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0486 - root_mean_squared_error: 0.2204
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0727 - root_mean_squared_error: 0.2696
# Epoch 5/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0392 - root_mean_squared_error: 0.1981
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0419 - root_mean_squared_error: 0.2047
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0429 - root_mean_squared_error: 0.2071
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0299 - root_mean_squared_error: 0.1730
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0219 - root_mean_squared_error: 0.1480
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0263 - root_mean_squared_error: 0.1622
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2047 - root_mean_squared_error: 0.4524
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0562 - root_mean_squared_error: 0.2370
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0746 - root_mean_squared_error: 0.2730
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0347 - root_mean_squared_error: 0.1864
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0375 - root_mean_squared_error: 0.1937
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0411 - root_mean_squared_error: 0.2026
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0277 - root_mean_squared_error: 0.1666
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0235 - root_mean_squared_error: 0.1534
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0198 - root_mean_squared_error: 0.1408
# 1/1 [==============================] - 0s 461ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2665 - root_mean_squared_error: 0.5162
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1130 - root_mean_squared_error: 0.3361
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0468 - root_mean_squared_error: 0.2162
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0629 - root_mean_squared_error: 0.2508
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0374 - root_mean_squared_error: 0.1934
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0283 - root_mean_squared_error: 0.1683
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0369 - root_mean_squared_error: 0.1920
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0311 - root_mean_squared_error: 0.1764
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0209 - root_mean_squared_error: 0.1447
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0193 - root_mean_squared_error: 0.1390
# 1/1 [==============================] - 0s 453ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2327 - root_mean_squared_error: 0.4824
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0793 - root_mean_squared_error: 0.2817
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0555 - root_mean_squared_error: 0.2356
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0344 - root_mean_squared_error: 0.1854
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0369 - root_mean_squared_error: 0.1920
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0184 - root_mean_squared_error: 0.1355
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0273 - root_mean_squared_error: 0.1654
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0170 - root_mean_squared_error: 0.1304
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0249 - root_mean_squared_error: 0.1577
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1332
# 1/1 [==============================] - 0s 463ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1919 - root_mean_squared_error: 0.4381
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0487 - root_mean_squared_error: 0.2206
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0375 - root_mean_squared_error: 0.1936
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0286 - root_mean_squared_error: 0.1691
# Epoch 5/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0184 - root_mean_squared_error: 0.1358
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0200 - root_mean_squared_error: 0.1413
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0154 - root_mean_squared_error: 0.1242
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0207 - root_mean_squared_error: 0.1439
# 1/1 [==============================] - 0s 452ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2340 - root_mean_squared_error: 0.4837
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0485 - root_mean_squared_error: 0.2202
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0508 - root_mean_squared_error: 0.2254
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0285 - root_mean_squared_error: 0.1688
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0398 - root_mean_squared_error: 0.1995
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0214 - root_mean_squared_error: 0.1463
# Epoch 7/10
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0197 - root_mean_squared_error: 0.1404
# Epoch 8/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0195 - root_mean_squared_error: 0.1396
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0135 - root_mean_squared_error: 0.1164
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0173 - root_mean_squared_error: 0.1317
# 1/1 [==============================] - 0s 457ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1782 - root_mean_squared_error: 0.4221
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0523 - root_mean_squared_error: 0.2287
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0563 - root_mean_squared_error: 0.2372
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0268 - root_mean_squared_error: 0.1636
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0397 - root_mean_squared_error: 0.1992
# Epoch 6/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0270 - root_mean_squared_error: 0.1642
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0282 - root_mean_squared_error: 0.1678
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0163 - root_mean_squared_error: 0.1276
# 1/1 [==============================] - 1s 500ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2719 - root_mean_squared_error: 0.5215
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1872 - root_mean_squared_error: 0.4326
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1004 - root_mean_squared_error: 0.3169
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0479 - root_mean_squared_error: 0.2189
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0808 - root_mean_squared_error: 0.2842
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0570 - root_mean_squared_error: 0.2387
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0374 - root_mean_squared_error: 0.1933
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0423 - root_mean_squared_error: 0.2057
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0468 - root_mean_squared_error: 0.2163
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0401 - root_mean_squared_error: 0.2004
# 1/1 [==============================] - 0s 457ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.3021 - root_mean_squared_error: 0.5496
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2286 - root_mean_squared_error: 0.4781
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1724 - root_mean_squared_error: 0.4152
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1017 - root_mean_squared_error: 0.3189
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0481 - root_mean_squared_error: 0.2194
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0766 - root_mean_squared_error: 0.2767
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0741 - root_mean_squared_error: 0.2722
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0424 - root_mean_squared_error: 0.2059
# Epoch 9/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0419 - root_mean_squared_error: 0.2048
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0502 - root_mean_squared_error: 0.2240
# 1/1 [==============================] - 0s 488ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2628 - root_mean_squared_error: 0.5127
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0677 - root_mean_squared_error: 0.2602
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0608 - root_mean_squared_error: 0.2466
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0580 - root_mean_squared_error: 0.2409
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0303 - root_mean_squared_error: 0.1741
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0372 - root_mean_squared_error: 0.1930
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0405 - root_mean_squared_error: 0.2012
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0275 - root_mean_squared_error: 0.1657
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0188 - root_mean_squared_error: 0.1370
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529
# 1/1 [==============================] - 0s 488ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1994 - root_mean_squared_error: 0.4465
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0534 - root_mean_squared_error: 0.2311
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0903 - root_mean_squared_error: 0.3006
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0429 - root_mean_squared_error: 0.2072
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0413 - root_mean_squared_error: 0.2031
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0473 - root_mean_squared_error: 0.2176
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0325 - root_mean_squared_error: 0.1802
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1424
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0254 - root_mean_squared_error: 0.1593
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0247 - root_mean_squared_error: 0.1571
# 1/1 [==============================] - 1s 511ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1822 - root_mean_squared_error: 0.4268
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0610 - root_mean_squared_error: 0.2469
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0575 - root_mean_squared_error: 0.2398
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0265 - root_mean_squared_error: 0.1626
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0350 - root_mean_squared_error: 0.1871
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0267 - root_mean_squared_error: 0.1635
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0169 - root_mean_squared_error: 0.1298
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0201 - root_mean_squared_error: 0.1417
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0130 - root_mean_squared_error: 0.1138
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247
# 1/1 [==============================] - 1s 514ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2178 - root_mean_squared_error: 0.4667
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0556 - root_mean_squared_error: 0.2359
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0655 - root_mean_squared_error: 0.2560
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0346 - root_mean_squared_error: 0.1860
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0376 - root_mean_squared_error: 0.1938
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0221 - root_mean_squared_error: 0.1487
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0245 - root_mean_squared_error: 0.1564
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277
# 1/1 [==============================] - 0s 467ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1217 - root_mean_squared_error: 0.3489
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0650 - root_mean_squared_error: 0.2550
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0333 - root_mean_squared_error: 0.1825
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0363 - root_mean_squared_error: 0.1905
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0327 - root_mean_squared_error: 0.1809
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0239 - root_mean_squared_error: 0.1545
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0217 - root_mean_squared_error: 0.1472
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0137 - root_mean_squared_error: 0.1168
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.1340
# 1/1 [==============================] - 0s 487ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.3515 - root_mean_squared_error: 0.5929
# Epoch 2/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0950 - root_mean_squared_error: 0.3083
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0471 - root_mean_squared_error: 0.2171
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0706 - root_mean_squared_error: 0.2657
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0447 - root_mean_squared_error: 0.2114
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0307 - root_mean_squared_error: 0.1751
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0397 - root_mean_squared_error: 0.1993
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0410 - root_mean_squared_error: 0.2025
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0305 - root_mean_squared_error: 0.1747
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0210 - root_mean_squared_error: 0.1447
# 1/1 [==============================] - 0s 451ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2902 - root_mean_squared_error: 0.5387
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1786 - root_mean_squared_error: 0.4226
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0731 - root_mean_squared_error: 0.2703
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0458 - root_mean_squared_error: 0.2141
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0630 - root_mean_squared_error: 0.2511
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0331 - root_mean_squared_error: 0.1819
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0322 - root_mean_squared_error: 0.1794
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0366 - root_mean_squared_error: 0.1913
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0186 - root_mean_squared_error: 0.1364
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.1629 - root_mean_squared_error: 0.4036
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0732 - root_mean_squared_error: 0.2706
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0466 - root_mean_squared_error: 0.2158
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0412 - root_mean_squared_error: 0.2030
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0372 - root_mean_squared_error: 0.1930
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0195 - root_mean_squared_error: 0.1398
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0193 - root_mean_squared_error: 0.1391
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0182 - root_mean_squared_error: 0.1350
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245
# 1/1 [==============================] - 0s 454ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2549 - root_mean_squared_error: 0.5049
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0525 - root_mean_squared_error: 0.2290
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0695 - root_mean_squared_error: 0.2636
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0334 - root_mean_squared_error: 0.1827
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0313 - root_mean_squared_error: 0.1768
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0359 - root_mean_squared_error: 0.1894
# Epoch 7/10
# ...
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0391 - root_mean_squared_error: 0.1977
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0439 - root_mean_squared_error: 0.2096
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0194 - root_mean_squared_error: 0.1394
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0202 - root_mean_squared_error: 0.1421
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0236 - root_mean_squared_error: 0.1536
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0198 - root_mean_squared_error: 0.1409
# 1/1 [==============================] - 1s 505ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2200 - root_mean_squared_error: 0.4690
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0470 - root_mean_squared_error: 0.2168
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0845 - root_mean_squared_error: 0.2907
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0305 - root_mean_squared_error: 0.1747
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0353 - root_mean_squared_error: 0.1880
# Epoch 6/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0444 - root_mean_squared_error: 0.2106
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0305 - root_mean_squared_error: 0.1745
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0210 - root_mean_squared_error: 0.1449
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0215 - root_mean_squared_error: 0.1465
# 1/1 [==============================] - 0s 463ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2558 - root_mean_squared_error: 0.5057
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0634 - root_mean_squared_error: 0.2519
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0818 - root_mean_squared_error: 0.2861
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0474 - root_mean_squared_error: 0.2176
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0346 - root_mean_squared_error: 0.1860
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0487 - root_mean_squared_error: 0.2206
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0406 - root_mean_squared_error: 0.2014
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0210 - root_mean_squared_error: 0.1448
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0280 - root_mean_squared_error: 0.1673
# 1/1 [==============================] - 0s 472ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2386 - root_mean_squared_error: 0.4885
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0811 - root_mean_squared_error: 0.2848
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0539 - root_mean_squared_error: 0.2322
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0624 - root_mean_squared_error: 0.2497
# Epoch 5/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0338 - root_mean_squared_error: 0.1839
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0365 - root_mean_squared_error: 0.1912
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0379 - root_mean_squared_error: 0.1947
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0264 - root_mean_squared_error: 0.1625
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0186 - root_mean_squared_error: 0.1362
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0236 - root_mean_squared_error: 0.1537
# 1/1 [==============================] - 0s 469ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2030 - root_mean_squared_error: 0.4506
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0550 - root_mean_squared_error: 0.2344
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0736 - root_mean_squared_error: 0.2713
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0342 - root_mean_squared_error: 0.1850
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0416 - root_mean_squared_error: 0.2040
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0369 - root_mean_squared_error: 0.1921
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0207 - root_mean_squared_error: 0.1440
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0204 - root_mean_squared_error: 0.1429
# Epoch 9/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0194 - root_mean_squared_error: 0.1392
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# 1/1 [==============================] - 0s 455ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2255 - root_mean_squared_error: 0.4749
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0779 - root_mean_squared_error: 0.2791
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0693 - root_mean_squared_error: 0.2633
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0591 - root_mean_squared_error: 0.2432
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0311 - root_mean_squared_error: 0.1765
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0437 - root_mean_squared_error: 0.2089
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0440 - root_mean_squared_error: 0.2097
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0291 - root_mean_squared_error: 0.1706
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575
# 1/1 [==============================] - 0s 463ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2020 - root_mean_squared_error: 0.4494
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0778 - root_mean_squared_error: 0.2788
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0639 - root_mean_squared_error: 0.2528
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0318 - root_mean_squared_error: 0.1783
# Epoch 5/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0327 - root_mean_squared_error: 0.1808
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0174 - root_mean_squared_error: 0.1320
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0226 - root_mean_squared_error: 0.1505
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0175 - root_mean_squared_error: 0.1322
# 1/1 [==============================] - 0s 478ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.1959 - root_mean_squared_error: 0.4426
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0574 - root_mean_squared_error: 0.2396
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0551 - root_mean_squared_error: 0.2347
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0267 - root_mean_squared_error: 0.1633
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0353 - root_mean_squared_error: 0.1878
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0163 - root_mean_squared_error: 0.1275
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0221 - root_mean_squared_error: 0.1486
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326
# 1/1 [==============================] - 0s 464ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2359 - root_mean_squared_error: 0.4857
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0658 - root_mean_squared_error: 0.2564
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0703 - root_mean_squared_error: 0.2652
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0382 - root_mean_squared_error: 0.1955
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0397 - root_mean_squared_error: 0.1992
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0354 - root_mean_squared_error: 0.1883
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0213 - root_mean_squared_error: 0.1459
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0263 - root_mean_squared_error: 0.1622
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0151 - root_mean_squared_error: 0.1230
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0172 - root_mean_squared_error: 0.1313
# 1/1 [==============================] - 0s 476ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2641 - root_mean_squared_error: 0.5139
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1199 - root_mean_squared_error: 0.3462
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0487 - root_mean_squared_error: 0.2207
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0679 - root_mean_squared_error: 0.2605
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0263 - root_mean_squared_error: 0.1620
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0319 - root_mean_squared_error: 0.1785
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0321 - root_mean_squared_error: 0.1793
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1380
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0207 - root_mean_squared_error: 0.1440
# 1/1 [==============================] - 0s 478ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2709 - root_mean_squared_error: 0.5205
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1129 - root_mean_squared_error: 0.3361
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0568 - root_mean_squared_error: 0.2383
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0566 - root_mean_squared_error: 0.2379
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0324 - root_mean_squared_error: 0.1800
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0400 - root_mean_squared_error: 0.2001
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0199 - root_mean_squared_error: 0.1411
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0139 - root_mean_squared_error: 0.1177
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0236 - root_mean_squared_error: 0.1535
# 1/1 [==============================] - 0s 461ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2594 - root_mean_squared_error: 0.5093
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0785 - root_mean_squared_error: 0.2801
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0921 - root_mean_squared_error: 0.3035
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0519 - root_mean_squared_error: 0.2279
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0466 - root_mean_squared_error: 0.2158
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0478 - root_mean_squared_error: 0.2186
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0324 - root_mean_squared_error: 0.1801
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0234 - root_mean_squared_error: 0.1528
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0276 - root_mean_squared_error: 0.1661
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0217 - root_mean_squared_error: 0.1474
# 1/1 [==============================] - 1s 559ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.1987 - root_mean_squared_error: 0.4458
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0473 - root_mean_squared_error: 0.2176
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0827 - root_mean_squared_error: 0.2877
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0438 - root_mean_squared_error: 0.2093
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0301 - root_mean_squared_error: 0.1735
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0436 - root_mean_squared_error: 0.2088
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0405 - root_mean_squared_error: 0.2014
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0242 - root_mean_squared_error: 0.1556
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0185 - root_mean_squared_error: 0.1362
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0238 - root_mean_squared_error: 0.1544
# 1/1 [==============================] - 0s 498ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.1869 - root_mean_squared_error: 0.4323
# Epoch 2/10
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0524 - root_mean_squared_error: 0.2289
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0709 - root_mean_squared_error: 0.2662
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0289 - root_mean_squared_error: 0.1701
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0403 - root_mean_squared_error: 0.2007
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0376 - root_mean_squared_error: 0.1939
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0216 - root_mean_squared_error: 0.1471
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0224 - root_mean_squared_error: 0.1496
# Epoch 10/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0122 - root_mean_squared_error: 0.1103
# 1/1 [==============================] - 1s 521ms/step

# %%
df_res = pd.DataFrame(
    {'MAPE': MAPE,
     'Direction': correction})
df_res.describe()
# Out:
#              MAPE   Direction
# count  100.000000  100.000000
# mean     1.420880    0.568947
# std      0.718715    0.112135
# min      0.648000    0.368421
# 25%      0.854500    0.473684
# 50%      1.223000    0.578947
# 75%      1.777000    0.644737
# max      4.584000    0.736842

# %%
plt.title("MAPE")
plt.plot(df_res['MAPE'])
plt.show()

# %%
plt.title("Direction")
plt.plot(df_res['Direction'])
plt.show()
