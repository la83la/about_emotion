# %% [markdown]
# 論文懶人包：<br>
# https://github.com/aronwc/mlsm/blob/master/papers/bollen10twitter/vlandeir.md<br>
# https://zhuanlan.zhihu.com/p/19944548<br>
# 使用到：<br>
# https://github.com/kbathina/sentiment-tools
#
# They create their own tool : Google-Profile Of Mood States (GPOMS), an extended version of POMS-bi. It is based on a lexicon of 964 terms and can measure human mood states in six mood dimensions : Calm, Alert, Sure, Vital, Kind and Happy.<br>
#
# 1. Calm: composed/anxious
# 2. Kind: agreeable/hostile
# 3. Happy: elated/depressed
# 4. Alert: confident/unsure
# 5. Sure: clearheaded/confuse
# 6. Vital: energetic/tired
#
# [詞彙表總覽]
# https://github.com/kbathina/sentiment-tools/blob/master/moodscores/data/GPOMS.csv

# %%
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import glob
import collections
import os
import re

# %%
# Function to Get the current
# working directory
def current_path():
    print("Current working directory before")
    print(os.getcwd())
 
 
# Driver's code
# Printing CWD before
current_path()
 
# Changing the CWD
os.chdir('../')
 
# Printing CWD after
current_path()
# Out:
# Current working directory before
# C:\Users\USER\Desktop\Prof_Hsieh_Project\about_emotion\English_derivative
# Current working directory before
# C:\Users\USER\Desktop\Prof_Hsieh_Project\about_emotion

# %% [markdown]
# # I. load tweets Data

# %%
condense_df = pd.read_pickle("Related_dataset/corpus.pkl")
condense_df.head()
# Out:
#                                              tweets_processed  tweet_size
# date_prune
# 2020-04-09  [targets, long, short, btc, url, url, realesta...      153618
# 2020-04-10  [short, sale, volume, short, url, shape, recov...       77124
# 2020-04-11  [jeffreyepstein, ghislainemaxwell, markepstein...       60031
# 2020-04-12  [rt, biggest, mistakes, apple, pc, maker, amaz...       66723
# 2020-04-13  [short, sale, volume, short, url, profit, earn...      136188

# %% [markdown]
# # II. Process the word list of sentiment

# %% [markdown]
#     try!

# %%
tweet = 'This tool is easy and fun to use!!!'

# %% [markdown]
#     pre emotion: 996 words!

# %%
from moodscores import gpoms
GPOMS = gpoms.GPOMS()

sentiment_gpoms_sum, tokens_gpoms_sum = GPOMS.Score(tweet,'Sum')
sentiment_gpoms_ave, tokens_gpoms_ave = GPOMS.Score(tweet,'Average')

# anxious, hostile, depressed, unsure, confused, tired
for dimension in sentiment_gpoms_sum.keys():
    print(dimension + ' score (Sum) =', sentiment_gpoms_sum[dimension])
    print(dimension + ' score (Average) =', sentiment_gpoms_ave[dimension])

print('Tokenized list =', tokens_gpoms_sum)
# Out:
# composed/anxious score (Sum) = 0.16
# composed/anxious score (Average) = 0.08
# agreeable/hostile score (Sum) = 0.436
# agreeable/hostile score (Average) = 0.218
# elated/depressed score (Sum) = 0.237
# elated/depressed score (Average) = 0.237
# confident/unsure score (Sum) = 0.763
# confident/unsure score (Average) = 0.3815
# clearheaded/confused score (Sum) = 0.14300000000000002
# clearheaded/confused score (Average) = 0.07150000000000001
# energetic/tired score (Sum) = 0.2509999999999999
# energetic/tired score (Average) = 0.12549999999999994
# Tokenized list = {'composed/anxious': ['easy', 'fun'], 'agreeable/hostile': ['easy', 'fun'], 'elated/depressed': ['fun'], 'confident/unsure': ['easy', 'fun'], 'clearheaded/confused': ['easy', 'fun'], 'energetic/tired': ['easy', 'fun']}

# %% [markdown]
# # III. Count the ratio of positive v.s. negative on the same day

# %%
merge_df = condense_df.copy()

def pre(list):
    return " ".join(list)
merge_df['GPOMS_preprocess_data'] = merge_df['tweets_processed'].map(pre)

def sentiment_GPOMS_sum(tweet):
    sentiment_gpoms_sum, tokens_gpoms_sum = GPOMS.Score(tweet,'Sum')
    tmp = []
    for dimension in sentiment_gpoms_sum.keys():
        tmp.append(sentiment_gpoms_sum[dimension])

    return tmp

def sentiment_GPOMS_avg(tweet):
    sentiment_gpoms_ave, tokens_gpoms_ave = GPOMS.Score(tweet,'Average')
    tmp = []
    for dimension in sentiment_gpoms_sum.keys():
        tmp.append(sentiment_gpoms_ave[dimension])

    return tmp


merge_df['GPOMS_sum'] = merge_df['GPOMS_preprocess_data'].map(sentiment_GPOMS_sum)
merge_df['GPOMS_avg'] = merge_df['GPOMS_preprocess_data'].map(sentiment_GPOMS_avg)

# %%
merge_df
# Out:
#                                              tweets_processed  tweet_size  \
# date_prune
# 2020-04-09  [targets, long, short, btc, url, url, realesta...      153618
# 2020-04-10  [short, sale, volume, short, url, shape, recov...       77124
# 2020-04-11  [jeffreyepstein, ghislainemaxwell, markepstein...       60031
# 2020-04-12  [rt, biggest, mistakes, apple, pc, maker, amaz...       66723
# 2020-04-13  [short, sale, volume, short, url, profit, earn...      136188
# ...                                                       ...         ...
# 2020-07-12  [want, learn, yaonology, service, visit, new, ...       81464
# 2020-07-13  [breaking, finances, valuation, url, url, url,...      205455
# 2020-07-14  [apple, air, pods, wired, charging, url, apple...      190338
# 2020-07-15  [joining, suggestions, url, url, short, sale, ...      182976
# 2020-07-16  [socially, trending, symbols, descending, orde...      156184
#
#                                         GPOMS_preprocess_data  \
# date_prune
# 2020-04-09  targets long short btc url url realestate beat...
# 2020-04-10  short sale volume short url shape recovery est...
# 2020-04-11  jeffreyepstein ghislainemaxwell markepstein lo...
# 2020-04-12  rt biggest mistakes apple pc maker amazon book...
# 2020-04-13  short sale volume short url profit earnings se...
# ...                                                       ...
# 2020-07-12  want learn yaonology service visit new website...
# 2020-07-13  breaking finances valuation url url url url ne...
# 2020-07-14  apple air pods wired charging url apple airpod...
# 2020-07-15  joining suggestions url url short sale vol sho...
# 2020-07-16  socially trending symbols descending order tra...
#
#                                                     GPOMS_sum  \
# date_prune
# 2020-04-09  [183.6299999999989, 539.3280000000003, -221.38...
# 2020-04-10  [93.32599999999992, 239.25200000000163, -94.83...
# 2020-04-11  [61.453999999999944, 349.1669999999983, -57.18...
# 2020-04-12  [87.4799999999995, 291.13600000000145, -60.822...
# 2020-04-13  [170.46399999999932, 537.4800000000009, -153.4...
# ...                                                       ...
# 2020-07-12  [102.06499999999987, 272.54400000000084, -99.6...
# 2020-07-13  [323.5660000000011, 834.1740000000028, -243.41...
# 2020-07-14  [321.867999999999, 715.0580000000004, -228.932...
# 2020-07-15  [255.56499999999664, 633.951000000004, -189.75...
# 2020-07-16  [198.26399999999845, 548.3010000000017, -199.0...
#
#                                                     GPOMS_avg
# date_prune
# 2020-04-09  [0.07336396324410663, 0.19152272727272737, -0....
# 2020-04-10  [0.09286169154228847, 0.19546732026143923, -0....
# 2020-04-11  [0.06188721047331314, 0.27888738019169196, -0....
# 2020-04-12  [0.0827625354777668, 0.21678034251675463, -0.0...
# 2020-04-13  [0.07969331463300576, 0.22274347285536714, -0....
# ...                                                       ...
# 2020-07-12  [0.07839093701996917, 0.18121276595744737, -0....
# 2020-07-13  [0.08231137115237881, 0.1830533245556293, -0.0...
# 2020-07-14  [0.09822032346658498, 0.18650443401147637, -0....
# 2020-07-15  [0.08456816677696778, 0.18461007571345486, -0....
# 2020-07-16  [0.08046428571428509, 0.18580176211453803, -0....
#
# [77 rows x 5 columns]

# %%
def max_index(list):
    return list.index(max(list))

# %%
merge_df['sum_index'] = merge_df['GPOMS_sum'].map(max_index)
merge_df['avg_index'] = merge_df['GPOMS_avg'].map(max_index)

# %%
merge_df.head()
# Out:
#                                              tweets_processed  tweet_size  \
# date_prune
# 2020-04-09  [targets, long, short, btc, url, url, realesta...      153618
# 2020-04-10  [short, sale, volume, short, url, shape, recov...       77124
# 2020-04-11  [jeffreyepstein, ghislainemaxwell, markepstein...       60031
# 2020-04-12  [rt, biggest, mistakes, apple, pc, maker, amaz...       66723
# 2020-04-13  [short, sale, volume, short, url, profit, earn...      136188
#
#                                         GPOMS_preprocess_data  \
# date_prune
# 2020-04-09  targets long short btc url url realestate beat...
# 2020-04-10  short sale volume short url shape recovery est...
# 2020-04-11  jeffreyepstein ghislainemaxwell markepstein lo...
# 2020-04-12  rt biggest mistakes apple pc maker amazon book...
# 2020-04-13  short sale volume short url profit earnings se...
#
#                                                     GPOMS_sum  \
# date_prune
# 2020-04-09  [183.6299999999989, 539.3280000000003, -221.38...
# 2020-04-10  [93.32599999999992, 239.25200000000163, -94.83...
# 2020-04-11  [61.453999999999944, 349.1669999999983, -57.18...
# 2020-04-12  [87.4799999999995, 291.13600000000145, -60.822...
# 2020-04-13  [170.46399999999932, 537.4800000000009, -153.4...
#
#                                                     GPOMS_avg  sum_index  \
# date_prune
# 2020-04-09  [0.07336396324410663, 0.19152272727272737, -0....          3
# 2020-04-10  [0.09286169154228847, 0.19546732026143923, -0....          3
# 2020-04-11  [0.06188721047331314, 0.27888738019169196, -0....          3
# 2020-04-12  [0.0827625354777668, 0.21678034251675463, -0.0...          3
# 2020-04-13  [0.07969331463300576, 0.22274347285536714, -0....          3
#
#             avg_index
# date_prune
# 2020-04-09          3
# 2020-04-10          3
# 2020-04-11          3
# 2020-04-12          3
# 2020-04-13          3

# %%
# merge_df.to_pickle("Related_dataset/GPOMS_result.pkl")

# %%
result = pd.DataFrame(merge_df, columns = ["tweet_size", "avg_index"])
result
# Out:
#             tweet_size  avg_index
# date_prune
# 2020-04-09      153618          3
# 2020-04-10       77124          3
# 2020-04-11       60031          3
# 2020-04-12       66723          3
# 2020-04-13      136188          3
# ...                ...        ...
# 2020-07-12       81464          3
# 2020-07-13      205455          3
# 2020-07-14      190338          3
# 2020-07-15      182976          3
# 2020-07-16      156184          3
#
# [77 rows x 2 columns]

# %% [markdown]
# ### 加入絕對值再去做比較

# %%
GPOMS = merge_df.copy()
    
GPOMS = GPOMS.drop(["tweets_processed", "tweet_size", "GPOMS_preprocess_data", "sum_index", "avg_index"], axis=1)
GPOMS.head()
# Out:
#                                                     GPOMS_sum  \
# date_prune
# 2020-04-09  [183.6299999999989, 539.3280000000003, -221.38...
# 2020-04-10  [93.32599999999992, 239.25200000000163, -94.83...
# 2020-04-11  [61.453999999999944, 349.1669999999983, -57.18...
# 2020-04-12  [87.4799999999995, 291.13600000000145, -60.822...
# 2020-04-13  [170.46399999999932, 537.4800000000009, -153.4...
#
#                                                     GPOMS_avg
# date_prune
# 2020-04-09  [0.07336396324410663, 0.19152272727272737, -0....
# 2020-04-10  [0.09286169154228847, 0.19546732026143923, -0....
# 2020-04-11  [0.06188721047331314, 0.27888738019169196, -0....
# 2020-04-12  [0.0827625354777668, 0.21678034251675463, -0.0...
# 2020-04-13  [0.07969331463300576, 0.22274347285536714, -0....

# %%
GPOMS_prim = GPOMS.copy()
GPOMS_prim[['Calm','Kind','Happy','Alert','Sure','Vital']] = pd.DataFrame(GPOMS.GPOMS_avg.tolist(), index= GPOMS.index)
GPOMS_prim = GPOMS_prim.drop(['GPOMS_sum', 'GPOMS_avg'], axis=1)
GPOMS_prim
# Out:
#                 Calm      Kind     Happy     Alert      Sure     Vital
# date_prune
# 2020-04-09  0.073364  0.191523 -0.115305  0.346767  0.136158  0.155670
# 2020-04-10  0.092862  0.195467 -0.102743  0.342314  0.130042  0.118410
# 2020-04-11  0.061887  0.278887 -0.064833  0.340592  0.101464  0.160457
# 2020-04-12  0.082763  0.216780 -0.062001  0.329557  0.111304  0.079260
# 2020-04-13  0.079693  0.222743 -0.091400  0.338160  0.130949  0.137338
# ...              ...       ...       ...       ...       ...       ...
# 2020-07-12  0.078391  0.181213 -0.097056  0.369545  0.147573  0.078480
# 2020-07-13  0.082311  0.183053 -0.082040  0.357759  0.154204  0.122646
# 2020-07-14  0.098220  0.186504 -0.089044  0.359141  0.150973  0.111742
# 2020-07-15  0.084568  0.184610 -0.079527  0.337375  0.146182  0.102206
# 2020-07-16  0.080464  0.185802 -0.098970  0.355024  0.149060  0.099416
#
# [77 rows x 6 columns]

# %%
# GPOMS_prim['Calm_pvn'] = (GPOMS_prim['Calm']>0)
# GPOMS_prim['Kind_pvn'] = (GPOMS_prim['Kind']>0)
# GPOMS_prim['Happy_pvn'] = (GPOMS_prim['Happy']>0)
# GPOMS_prim['Alert_pvn'] = (GPOMS_prim['Alert']>0)
# GPOMS_prim['Sure_pvn'] = (GPOMS_prim['Sure']>0)
# GPOMS_prim['Vital_pvn'] = (GPOMS_prim['Vital']>0)

# %%
GPOMS_prim['Max_value'] = GPOMS_prim.apply(lambda x: max(x.min(), x.max(), key=abs),axis=1)
GPOMS_prim['Max_type'] = GPOMS_prim.idxmax(axis=1)
GPOMS_prim.head()
# Out:
#                 Calm      Kind     Happy     Alert      Sure     Vital  \
# date_prune
# 2020-04-09  0.073364  0.191523 -0.115305  0.346767  0.136158  0.155670
# 2020-04-10  0.092862  0.195467 -0.102743  0.342314  0.130042  0.118410
# 2020-04-11  0.061887  0.278887 -0.064833  0.340592  0.101464  0.160457
# 2020-04-12  0.082763  0.216780 -0.062001  0.329557  0.111304  0.079260
# 2020-04-13  0.079693  0.222743 -0.091400  0.338160  0.130949  0.137338
#
#             Max_value Max_type
# date_prune
# 2020-04-09   0.346767    Alert
# 2020-04-10   0.342314    Alert
# 2020-04-11   0.340592    Alert
# 2020-04-12   0.329557    Alert
# 2020-04-13   0.338160    Alert

# %%
GPOMS_prim['Max_type'].describe()
# Out:
# count        77
# unique        1
# top       Alert
# freq         77
# Name: Max_type, dtype: object

# %%
GPOMS_prim['Max_value'].mean()
# Out:
# 0.3531023184882754

# %%
tmp = list(GPOMS_prim['Max_type'])
dict((a, tmp.count(a)) for a in tmp)
# Out:
# {'Alert': 77}

# %% [markdown]
# 很奇怪，77天都是Alert最高，這個資料好像不應該有這個特性?? (他不是企業推文ㄌ)- wa

# %%
# 新資料有好幾天都沒有推文資料，不是連續ㄉ:0
tmp = GPOMS_prim.copy()
tmp = tmp.reset_index()

my_range = pd.date_range(
  start="2020-04-09", end="2020-07-16", freq='B')
 
print(my_range.difference(tmp['date_prune']))
# Out:
# DatetimeIndex(['2020-04-30', '2020-05-01', '2020-05-11', '2020-05-12',
#                '2020-05-13', '2020-05-14', '2020-05-15', '2020-05-18',
#                '2020-05-19', '2020-05-20', '2020-05-21', '2020-05-22',
#                '2020-05-25', '2020-05-26', '2020-05-27', '2020-06-12'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## IV. lemmatization

# %%
import nltk 
from nltk import word_tokenize, pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return None
    
def lemmatization(sentence):
    tokens = word_tokenize(sentence)  # 分詞
    tagged_sent = pos_tag(tokens)     # 獲取單詞詞性

    wnl = WordNetLemmatizer()
    lemmas_sent = []
    for tag in tagged_sent:
        wordnet_pos = get_wordnet_pos(tag[1]) or wordnet.NOUN
        lemmas_sent.append(wnl.lemmatize(tag[0], pos=wordnet_pos)) # 詞形還原

    return lemmas_sent

# %%
# 跑很久，到這邊我就沒繼續了，你可以再看看找不找的到原因- wa

def pre(list):
    return " ".join(list)

def sentiment_GPOMS_sum(tweet):
    sentiment_gpoms_sum, tokens_gpoms_sum = GPOMS.Score(tweet,'Sum')
    tmp = []
    for dimension in sentiment_gpoms_sum.keys():
        tmp.append(sentiment_gpoms_sum[dimension])

    return tmp

def sentiment_GPOMS_avg(tweet):
    sentiment_gpoms_ave, tokens_gpoms_ave = GPOMS.Score(tweet,'Average')
    tmp = []
    for dimension in sentiment_gpoms_sum.keys():
        tmp.append(sentiment_gpoms_ave[dimension])
    return tmp

merge_df = condense_df.copy()
merge_df['GPOMS_preprocess_data'] = merge_df['tweets_processed'].map(pre)
del merge_df['tweets_processed']

merge_df['lemmatization'] = merge_df['GPOMS_preprocess_data'].map(lemmatization)
del merge_df['GPOMS_preprocess_data']

merge_df['GPOMS_preprocess_data'] = merge_df['lemmatization'].map(pre)
del merge_df['lemmatization']
del merge_df['tweet_size']

merge_df
# Out:
# KeyboardInterrupt

# %%
merge_df['GPOMS_sum_lemmatized'] = merge_df['GPOMS_preprocess_data'].map(sentiment_GPOMS_sum)
merge_df['GPOMS_avg_lemmatized'] = merge_df['GPOMS_preprocess_data'].map(sentiment_GPOMS_avg)

merge_df = merge_df.drop(["GPOMS_preprocess_data"], axis=1)

# %%
merge_df.head()

# %%
GPOMS.index

# %%
GPOMS = merge_df
GPOMS_prim = merge_df
GPOMS_prim[['Calm','Kind','Happy','Alert','Sure','Vital']] = pd.DataFrame(GPOMS.GPOMS_avg_lemmatized.tolist(), index= GPOMS.index)
GPOMS_prim = GPOMS_prim.drop(['GPOMS_sum_lemmatized', 'GPOMS_avg_lemmatized'], axis=1)
GPOMS_prim

# %%
GPOMS_prim['Max_value'] = GPOMS_prim.apply(lambda x: max(x.min(), x.max(), key=abs),axis=1)
GPOMS_prim['Max_type'] = GPOMS_prim.idxmax(axis=1)
GPOMS_prim.head()

# %%
GPOMS_prim['Max_value'].mean()

# %%
tmp = list(GPOMS_prim['Max_type'])
dict((a, tmp.count(a)) for a in tmp)
