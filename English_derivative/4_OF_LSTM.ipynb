# %%
import datetime
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evaluation
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
import tensorflow as tf 
from scipy import stats

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # I. Load data

# %%
OF = pd.read_pickle("Related_dataset/Opinion_Finder_result.pkl")
GPOMS = pd.read_pickle("Related_dataset/GPOMS_result.pkl")
DJIA = pd.read_pickle("Related_dataset/DJIA_filled_missing_value.pkl")

# %% [markdown]
# # II. Prepare dataset

# %%
# process OF dataframe
OF_prim = OF.drop(columns=['tweets_processed', 'tweet_size'])
OF_prim = OF_prim.reset_index()
OF_prim = OF_prim.rename({'date_prune': 'Dates'}, axis=1) 

# process GPOMS dataframe
GPOMS_pivot = GPOMS.drop(columns=['tweets_processed', 'tweet_size', 'GPOMS_preprocess_data', 'GPOMS_sum','sum_index', 'avg_index'])
GPOMS_pivot[['Calm','Kind','Happy','Alert','Sure','Vital']] = pd.DataFrame(GPOMS.GPOMS_avg.tolist(), index= GPOMS.index)
GPOMS_pivot = GPOMS_pivot.drop(['GPOMS_avg'], axis=1)
GPOMS_pivot = GPOMS_pivot.reset_index()
GPOMS_pivot = GPOMS_pivot.rename({'date_prune': 'Dates'}, axis=1) 

# process DJIA dataframe
DJIA['Dates'] = DJIA['Dates'].astype(str)

# %%
combine_df = OF_prim.merge(GPOMS_pivot, on='Dates')
combine_df = combine_df.merge(DJIA, on='Dates', how='inner')
combine_df
# Out:
#          Dates  OF_transform      Calm      Kind     Happy     Alert  \
# 0   2020-04-09     -0.380042  0.073364  0.191523 -0.115305  0.346767
# 1   2020-04-10      0.740977  0.092862  0.195467 -0.102743  0.342314
# 2   2020-04-11      0.456476  0.061887  0.278887 -0.064833  0.340592
# 3   2020-04-12      0.403397  0.082763  0.216780 -0.062001  0.329557
# 4   2020-04-13      0.144374  0.079693  0.222743 -0.091400  0.338160
# ..         ...           ...       ...       ...       ...       ...
# 72  2020-07-12      0.235669  0.078391  0.181213 -0.097056  0.369545
# 73  2020-07-13     -0.322718  0.082311  0.183053 -0.082040  0.357759
# 74  2020-07-14     -0.271762  0.098220  0.186504 -0.089044  0.359141
# 75  2020-07-15      0.002123  0.084568  0.184610 -0.079527  0.337375
# 76  2020-07-16     -0.165605  0.080464  0.185802 -0.098970  0.355024
#
#         Sure     Vital         Close
# 0   0.136158  0.155670  23719.369141
# 1   0.130042  0.118410  23555.069336
# 2   0.101464  0.160457  23472.919434
# 3   0.111304  0.079260  23431.844482
# 4   0.130949  0.137338  23390.769531
# ..       ...       ...           ...
# 72  0.147573  0.078480  26083.175781
# 73  0.154204  0.122646  26085.800781
# 74  0.150973  0.111742  26642.589844
# 75  0.146182  0.102206  26870.099609
# 76  0.149060  0.099416  26734.710938
#
# [77 rows x 9 columns]

# %% [markdown]
# # III. Build Neural Network model to predict DJIA
# input:
# 1. The past 5 days of DJIA values
# 2. Opinion Finder mood data (past 5 days)
#
# Time period (in thesis):
# > Train: 2008-2-28 ~ 2008-11-28 (10 months)
#
# > Test: 2008-12-1 ~ 2008-12-19 (19 days)
#
# Time period (in this project):
# > Train: 2020-4-9 ~ 2020-6-23 (54 days, some missing data)
#
# > Test: 2020-6-24 ~ 2022-7-16 (18 days)

# %%
threshold = 54
WINDOW_SIZE = 5

# %% [markdown]
# Part 1 : 只提供過去五天收盤價資訊
#
# Single variable
#
# > X[0]: [[ [1], [2], [3]]]
#
# > y[0]: [4]

# %%
def mape(actual, predict): 
    actual, predict = np.array(actual), np.array(predict)
    return np.mean(np.abs((actual - predict) / actual)) * 100

def direction(actual, predict): 
    prev_act = actual[0]
    prev_pred = predict[0]
    true = []
    res = []
    for i, j in zip(actual[1:], predict[1:]): 
        if i>=prev_act:
            true.append(1)
        else:
            true.append(-1)
        if j>=prev_pred:
            res.append(1)
        else:
            res.append(-1)
        prev_act = i
        prev_pred = j
    denorminator = len(actual) -1
    numerator = 0
    for i, j in zip(true, res):
        if i==j:
            numerator += 1
    return (numerator / denorminator)

# %%
tmp = combine_df['Close']
tmp = tmp.to_numpy().reshape(-1, 1)
scaler = MinMaxScaler()
temp = scaler.fit_transform(tmp)
temp.shape
# Out:
# (77, 1)

# %%
def df_to_X_y(df, window_size):
    X = []
    y = []
    for i in range(len(df)-window_size):
        row = [a for a in df[i:i+window_size]]
        X.append(row)
        label = df[i+window_size]
        y.append(label)
    return np.array(X), np.array(y)

# %%
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape # NUMBER of data, WINDOW_size, number of feature
# Out:
# ((72, 5, 1), (72, 1))

# %%
X_train1, y_train1 = X1[:threshold], y1[:threshold]
X_test1, y_test1 = X1[threshold:], y1[threshold:]
X_train1.shape, y_train1.shape, X_test1.shape, y_test1.shape
# Out:
# ((54, 5, 1), (54, 1), (18, 5, 1), (18, 1))

# %%
model1 = Sequential()
model1.add(InputLayer((WINDOW_SIZE, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 64)                16896
#
#  dense_8 (Dense)             (None, 8)                 520
#
#  dense_9 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])

model1.fit(X_train1, y_train1, epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 7ms/step - loss: 0.1929 - root_mean_squared_error: 0.4393
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0653 - root_mean_squared_error: 0.2555
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0268 - root_mean_squared_error: 0.1636
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0418 - root_mean_squared_error: 0.2044
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0549 - root_mean_squared_error: 0.2343
# Epoch 6/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0337 - root_mean_squared_error: 0.1834
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0212 - root_mean_squared_error: 0.1457
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0276 - root_mean_squared_error: 0.1662
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0286 - root_mean_squared_error: 0.1691
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326

# %%
def plot_modal_res(df, tp):
    plt.title(f"{tp} result")
    plt.plot(df[f'{tp} Predictions'], c='b')
    plt.plot(df['Actuals'], c='g')
    plt.legend(["Modal Predict", "Ground True"], loc ="lower right")
    plt.show()

# %%
# train result
train_predictions = model1.predict(X_train1).flatten()
pred = scaler.inverse_transform(train_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_train1)
act = act.reshape(-1,)

train_results1 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

plot_modal_res(train_results1, 'Train')
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000207ECECA430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 4ms/step

# %%
# Test result
test_predictions = model1.predict(X_test1).flatten()
pred = scaler.inverse_transform(test_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_test1)
act = act.reshape(-1,)

test_results1 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})

plot_modal_res(test_results1, 'Test')
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %% [markdown]
# A little bit overfitting.
#
# ***Try to use delta***

# %%
# 加入delta
Data_new = combine_df.copy()

Data_new['tomorrow'] = Data_new['Close'].shift(-1)
Data_new.drop(Data_new.tail(1).index, inplace=True)
Data_new['delta'] = Data_new['tomorrow'] - Data_new['Close']
tmp3 = Data_new['delta']
tmp3 = tmp3.to_numpy().reshape(-1, 1)
scaler = MinMaxScaler()
temp3 = scaler.fit_transform(tmp3)

WINDOW_SIZE = 3
X3, y3 = df_to_X_y(temp3, WINDOW_SIZE)
X3.shape, y3.shape # NUMBER of data, WINDOW_size, number of feature

X_train3, y_train3 = X3[:threshold], y3[:threshold]
X_test3, y_test3 = X3[threshold:], y3[threshold:]
X_train3.shape, y_train3.shape, X_test3.shape, y_test3.shape
# Out:
# ((54, 3, 1), (54, 1), (19, 3, 1), (19, 1))

# %%
model3 = Sequential()
model3.add(InputLayer((WINDOW_SIZE, 1)))
model3.add(LSTM(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))

model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                16896
#
#  dense_2 (Dense)             (None, 8)                 520
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])

model3.fit(X_train3, y_train3, epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.4241 - root_mean_squared_error: 0.6512
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1303 - root_mean_squared_error: 0.3610
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0321 - root_mean_squared_error: 0.1792
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0866 - root_mean_squared_error: 0.2943
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0403 - root_mean_squared_error: 0.2008
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0263 - root_mean_squared_error: 0.1622
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0420 - root_mean_squared_error: 0.2050
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0497 - root_mean_squared_error: 0.2230
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0418 - root_mean_squared_error: 0.2044
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0287 - root_mean_squared_error: 0.1695

# %%
# train result
train_predictions = model3.predict(X_train3).flatten()
pred = scaler.inverse_transform(train_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_train3)
act = act.reshape(-1,)

train_results3 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

plot_modal_res(train_results3, 'Train')
# Out:
# 2/2 [==============================] - 1s 3ms/step

# %%
# Test result
test_predictions = model3.predict(X_test3).flatten()
pred = scaler.inverse_transform(test_predictions.reshape(-1, 1))
pred = pred.reshape(-1,)
act = scaler.inverse_transform(y_test3)
act = act.reshape(-1,)

test_results3 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})

plot_modal_res(test_results3, 'Test')
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
# Part 1: past three days' DJIA data
print("MAPE:", mape(test_results3['Actuals'], test_results3['Test Predictions']).round(3), "%")
print("Directional correction rate:", "{0:.0%}".format(direction(test_results3['Actuals'], test_results3['Test Predictions'])) )
# Out:
# MAPE: 399.208 %
# Directional correction rate: 33%

# %% [markdown]
# 結果真d差

# %% [markdown]
# ***Part 2: 提供過去3天的DJIA + OF 資料***
#
# multi-variable
#
# > X[0]: [[ [1-1, 1-2, ..], [2-1, 2-2, ...], [3-1, 3-2, ...]]]
#
# > y[0]: [4]

# %%
temp2 = combine_df[['Close','OF_transform']]
mms_close = MinMaxScaler()
mms_OF = MinMaxScaler()
temp2['Close'] = mms_close.fit_transform(np.array(temp2['Close']).reshape(-1, 1))
temp2['OF_transform'] = mms_OF.fit_transform(np.array(temp2['OF_transform']).reshape(-1, 1))

# %%
def df_to_X_y2(df, window_size=3):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %%
NUM_FEATURE = 2
X2, y2 = df_to_X_y2(temp2, WINDOW_SIZE)
X2.shape, y2.shape # number of data, # size of window, number of features
# Out:
# ((72, 5, 2), (72,))

# %%
X_train2, y_train2 = X2[:threshold], y2[:threshold]
X_test2, y_test2 = X2[threshold:], y2[threshold:]
X_train2.shape, y_train2.shape, X_test2.shape, y_test2.shape
# Out:
# ((54, 5, 2), (54,), (18, 5, 2), (18,))

# %%
model2 = Sequential()
model2.add(InputLayer((WINDOW_SIZE, NUM_FEATURE)))
model2.add(LSTM(64))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 64)                17152
#
#  dense_10 (Dense)            (None, 8)                 520
#
#  dense_11 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 17,681
# Trainable params: 17,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])
model2.fit(X_train2, y_train2, epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2849 - root_mean_squared_error: 0.5338
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1263 - root_mean_squared_error: 0.3554
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0456 - root_mean_squared_error: 0.2135
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0784 - root_mean_squared_error: 0.2800
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0337 - root_mean_squared_error: 0.1837
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0449 - root_mean_squared_error: 0.2120
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0537 - root_mean_squared_error: 0.2317
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0409 - root_mean_squared_error: 0.2022
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0268 - root_mean_squared_error: 0.1636
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0304 - root_mean_squared_error: 0.1745

# %%
# train result
train_predictions2 = model2.predict(X_train2).flatten()
pred = mms_close.inverse_transform(train_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_train2.reshape(-1, 1))
act = act.reshape(-1,)

train_results2 = pd.DataFrame(data={
    'Train Predictions':pred, 
    'Actuals':act})

plot_modal_res(train_results2, 'Train')
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020780941A60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step

# %%
# Test result
test_predictions2 = model2.predict(X_test2).flatten()
pred = mms_close.inverse_transform(test_predictions2.reshape(-1, 1))
pred = pred.reshape(-1,)
act = mms_close.inverse_transform(y_test2.reshape(-1, 1))
act = act.reshape(-1,)

test_results2 = pd.DataFrame(data={
    'Test Predictions':pred, 
    'Actuals':act})

plot_modal_res(test_results2, 'Test')
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %% [markdown]
# # IV. Compute MAPE & Direction correct rate

# %%
# Part 1: past three days' DJIA data
print("MAPE:", mape(test_results1['Actuals'], test_results1['Test Predictions']).round(3), "%")
print("Directional correction rate:", "{0:.0%}".format(direction(test_results1['Actuals'], test_results1['Test Predictions'])) )
# Out:
# MAPE: 2.14 %
# Directional correction rate: 71%

# %%
plot_modal_res(test_results1, 'Test')

# %%
# Part 2: past three days' DJIA data + Opinion Finder data
print("MAPE: ", mape(test_results2['Actuals'], test_results2['Test Predictions']).round(3), "%")
print("Directional correction rate:", "{0:.0%}".format(direction(test_results2['Actuals'], test_results2['Test Predictions'])) )
# Out:
# MAPE:  1.108 %
# Directional correction rate: 59%

# %%
plot_modal_res(test_results2, 'Test')

# %% [markdown]
# reference:
#
# https://colab.research.google.com/drive/1b3CUJuDOmPmNdZFH3LQDmt5F0K3FZhqD?usp=sharing#scrollTo=FmwshpETs-jE

# %%
tmp = test_results2.copy()
tmp['pred_shift'] = tmp['Test Predictions'].shift(1)
tmp['Actuals_shift'] = tmp['Actuals'].shift(1)

tmp['pred_dire'] = tmp['Test Predictions'] - tmp['pred_shift']
tmp['pred_dire'] = tmp['pred_dire'].apply(lambda x: x>0)

tmp['act_dire'] = tmp['Actuals'] - tmp['Actuals_shift']
tmp['act_dire'] = tmp['act_dire'].apply(lambda x: x>0)
tmp
# Out:
#     Test Predictions       Actuals    pred_shift  Actuals_shift  pred_dire  \
# 0       25473.826172  25595.800781           NaN            NaN      False
# 1       25493.314453  25812.880859  25473.826172   25595.800781       True
# 2       25520.410156  25734.970703  25493.314453   25812.880859       True
# 3       25559.859375  25827.359375  25520.410156   25734.970703       True
# 4       25645.505859  26057.194336  25559.859375   25827.359375       True
# 5       25853.138672  26172.111816  25645.505859   26057.194336       True
# 6       25958.652344  26229.570557  25853.138672   26172.111816       True
# 7       26073.093750  26287.029297  25958.652344   26229.570557       True
# 8       26066.847656  25890.179687  26073.093750   26287.029297      False
# 9       25985.822266  26067.279297  26066.847656   25890.179687      False
# 10      25873.705078  25706.089844  25985.822266   26067.279297      False
# 11      25825.832031  26075.300781  25873.705078   25706.089844      False
# 12      25882.570312  26080.550781  25825.832031   26075.300781       True
# 13      25943.798828  26083.175781  25882.570312   26080.550781       True
# 14      25993.046875  26085.800781  25943.798828   26083.175781       True
# 15      25904.443359  26642.589844  25993.046875   26085.800781      False
# 16      25965.294922  26870.099609  25904.443359   26642.589844       True
# 17      26085.695312  26734.710938  25965.294922   26870.099609       True
#
#     act_dire
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8      False
# 9       True
# 10     False
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17     False

# %% [markdown]
# # Confidence Interval

# %%
MAPE = []
correction = []
NUM_FEATURE = 2

for i in range(100):
    model_k = Sequential()
    model_k.add(InputLayer((WINDOW_SIZE, NUM_FEATURE)))
    model_k.add(LSTM(64))
    model_k.add(Dense(8, 'relu'))
    model_k.add(Dense(1, 'linear'))

    model_k.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.01), metrics=[RootMeanSquaredError()])
    model_k.fit(X_train2, y_train2, epochs=10)

    # Test result
    test_predictions2 = model_k.predict(X_test2).flatten()
    pred = mms_close.inverse_transform(test_predictions2.reshape(-1, 1))
    pred = pred.reshape(-1,)
    act = mms_close.inverse_transform(y_test2.reshape(-1, 1))
    act = act.reshape(-1,)

    test_results2 = pd.DataFrame(data={
        'Test Predictions':pred, 
        'Actuals':act})

    # Part 2: past three days' DJIA data + Opinion Finder data
    MAPE.append(mape(test_results2['Actuals'], test_results2['Test Predictions']).round(3))
    correction.append(direction(test_results2['Actuals'], test_results2['Test Predictions']))
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.2738 - root_mean_squared_error: 0.5232
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2242 - root_mean_squared_error: 0.4735
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1354 - root_mean_squared_error: 0.3680
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0940 - root_mean_squared_error: 0.3066
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0749 - root_mean_squared_error: 0.2737
# Epoch 6/10
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0444 - root_mean_squared_error: 0.2108
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0487 - root_mean_squared_error: 0.2206
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0566 - root_mean_squared_error: 0.2380
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0479 - root_mean_squared_error: 0.2188
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0342 - root_mean_squared_error: 0.1849
# 1/1 [==============================] - 1s 538ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1760 - root_mean_squared_error: 0.4196
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0854 - root_mean_squared_error: 0.2922
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0400 - root_mean_squared_error: 0.1999
# Epoch 4/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0517 - root_mean_squared_error: 0.2274
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0289 - root_mean_squared_error: 0.1701
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0264 - root_mean_squared_error: 0.1625
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0263 - root_mean_squared_error: 0.1621
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0260 - root_mean_squared_error: 0.1611
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0207 - root_mean_squared_error: 0.1440
# 1/1 [==============================] - 0s 468ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1729 - root_mean_squared_error: 0.4158
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0512 - root_mean_squared_error: 0.2262
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0604 - root_mean_squared_error: 0.2458
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0373 - root_mean_squared_error: 0.1932
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0431 - root_mean_squared_error: 0.2076
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0268 - root_mean_squared_error: 0.1638
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0214 - root_mean_squared_error: 0.1463
# Epoch 8/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0246 - root_mean_squared_error: 0.1569
# Epoch 9/10
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425
# 1/1 [==============================] - 1s 523ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.1626 - root_mean_squared_error: 0.4032
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0594 - root_mean_squared_error: 0.2437
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0313 - root_mean_squared_error: 0.1768
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0251 - root_mean_squared_error: 0.1584
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0278 - root_mean_squared_error: 0.1669
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0206 - root_mean_squared_error: 0.1435
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0215 - root_mean_squared_error: 0.1465
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0233 - root_mean_squared_error: 0.1525
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0201 - root_mean_squared_error: 0.1419
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.2896 - root_mean_squared_error: 0.5382
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2531 - root_mean_squared_error: 0.5031
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2114 - root_mean_squared_error: 0.4598
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1591 - root_mean_squared_error: 0.3989
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0856 - root_mean_squared_error: 0.2926
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0549 - root_mean_squared_error: 0.2344
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0819 - root_mean_squared_error: 0.2861
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0478 - root_mean_squared_error: 0.2187
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0469 - root_mean_squared_error: 0.2165
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0545 - root_mean_squared_error: 0.2334
# 1/1 [==============================] - 0s 477ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.1303 - root_mean_squared_error: 0.3609
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0464 - root_mean_squared_error: 0.2155
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0350 - root_mean_squared_error: 0.1872
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0222 - root_mean_squared_error: 0.1489
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0232 - root_mean_squared_error: 0.1523
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0178 - root_mean_squared_error: 0.1335
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0133 - root_mean_squared_error: 0.1154
# 1/1 [==============================] - 0s 476ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 7ms/step - loss: 0.2489 - root_mean_squared_error: 0.4989
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0557 - root_mean_squared_error: 0.2361
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0666 - root_mean_squared_error: 0.2581
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0335 - root_mean_squared_error: 0.1830
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0419 - root_mean_squared_error: 0.2046
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0374 - root_mean_squared_error: 0.1935
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0211 - root_mean_squared_error: 0.1454
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0271 - root_mean_squared_error: 0.1646
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0264 - root_mean_squared_error: 0.1626
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293
# 1/1 [==============================] - 0s 474ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.1682 - root_mean_squared_error: 0.4101
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0709 - root_mean_squared_error: 0.2662
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0358 - root_mean_squared_error: 0.1892
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0352 - root_mean_squared_error: 0.1877
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0195 - root_mean_squared_error: 0.1397
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0246 - root_mean_squared_error: 0.1568
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0215 - root_mean_squared_error: 0.1467
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281
# 1/1 [==============================] - 0s 498ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 9ms/step - loss: 0.2267 - root_mean_squared_error: 0.4761
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0549 - root_mean_squared_error: 0.2344
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0819 - root_mean_squared_error: 0.2862
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0373 - root_mean_squared_error: 0.1931
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0464 - root_mean_squared_error: 0.2154
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0425 - root_mean_squared_error: 0.2060
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0242 - root_mean_squared_error: 0.1556
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0285 - root_mean_squared_error: 0.1689
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0243 - root_mean_squared_error: 0.1558
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0187 - root_mean_squared_error: 0.1368
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.1910 - root_mean_squared_error: 0.4370
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0654 - root_mean_squared_error: 0.2557
# Epoch 3/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0534 - root_mean_squared_error: 0.2312
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0361 - root_mean_squared_error: 0.1900
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0459 - root_mean_squared_error: 0.2142
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0383 - root_mean_squared_error: 0.1957
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0249 - root_mean_squared_error: 0.1578
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0275 - root_mean_squared_error: 0.1658
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0222 - root_mean_squared_error: 0.1491
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410
# 1/1 [==============================] - 0s 494ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.1525 - root_mean_squared_error: 0.3905
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0596 - root_mean_squared_error: 0.2441
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0227 - root_mean_squared_error: 0.1508
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0419 - root_mean_squared_error: 0.2047
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0286 - root_mean_squared_error: 0.1690
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0235 - root_mean_squared_error: 0.1533
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0262 - root_mean_squared_error: 0.1619
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0150 - root_mean_squared_error: 0.1225
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0221 - root_mean_squared_error: 0.1488
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0191 - root_mean_squared_error: 0.1383
# 1/1 [==============================] - 0s 498ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 13ms/step - loss: 0.1527 - root_mean_squared_error: 0.3908
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0617 - root_mean_squared_error: 0.2484
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0293 - root_mean_squared_error: 0.1711
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0388 - root_mean_squared_error: 0.1969
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0213 - root_mean_squared_error: 0.1458
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0172 - root_mean_squared_error: 0.1310
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0171 - root_mean_squared_error: 0.1309
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0201 - root_mean_squared_error: 0.1417
# 1/1 [==============================] - 0s 471ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2058 - root_mean_squared_error: 0.4537
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0589 - root_mean_squared_error: 0.2427
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0352 - root_mean_squared_error: 0.1876
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0380 - root_mean_squared_error: 0.1949
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0269 - root_mean_squared_error: 0.1642
# Epoch 6/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0226 - root_mean_squared_error: 0.1504
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0195 - root_mean_squared_error: 0.1396
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211
# 1/1 [==============================] - 1s 524ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 12ms/step - loss: 0.1629 - root_mean_squared_error: 0.4036
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0513 - root_mean_squared_error: 0.2265
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0266 - root_mean_squared_error: 0.1630
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0333 - root_mean_squared_error: 0.1825
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0243 - root_mean_squared_error: 0.1559
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0177 - root_mean_squared_error: 0.1332
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253
# 1/1 [==============================] - 0s 470ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.1195 - root_mean_squared_error: 0.3457
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0477 - root_mean_squared_error: 0.2184
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0273 - root_mean_squared_error: 0.1652
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0200 - root_mean_squared_error: 0.1416
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0187 - root_mean_squared_error: 0.1368
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285
# Epoch 7/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0171 - root_mean_squared_error: 0.1309
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297
# 1/1 [==============================] - 0s 484ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.1428 - root_mean_squared_error: 0.3779
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0661 - root_mean_squared_error: 0.2571
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0332 - root_mean_squared_error: 0.1823
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0387 - root_mean_squared_error: 0.1968
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0222 - root_mean_squared_error: 0.1491
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0224 - root_mean_squared_error: 0.1498
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0212 - root_mean_squared_error: 0.1457
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0173 - root_mean_squared_error: 0.1314
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0148 - root_mean_squared_error: 0.1216
# 1/1 [==============================] - 1s 506ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.2138 - root_mean_squared_error: 0.4624
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0632 - root_mean_squared_error: 0.2515
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0317 - root_mean_squared_error: 0.1779
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0442 - root_mean_squared_error: 0.2103
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0278 - root_mean_squared_error: 0.1668
# Epoch 6/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0282 - root_mean_squared_error: 0.1681
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0205 - root_mean_squared_error: 0.1432
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0217 - root_mean_squared_error: 0.1474
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0153 - root_mean_squared_error: 0.1239
# 1/1 [==============================] - 0s 485ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 8ms/step - loss: 0.2375 - root_mean_squared_error: 0.4873
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0596 - root_mean_squared_error: 0.2441
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0609 - root_mean_squared_error: 0.2468
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0314 - root_mean_squared_error: 0.1771
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0413 - root_mean_squared_error: 0.2033
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0254 - root_mean_squared_error: 0.1594
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0224 - root_mean_squared_error: 0.1496
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0267 - root_mean_squared_error: 0.1633
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0161 - root_mean_squared_error: 0.1271
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0219 - root_mean_squared_error: 0.1480
# 1/1 [==============================] - 0s 479ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 6ms/step - loss: 0.2337 - root_mean_squared_error: 0.4834
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0601 - root_mean_squared_error: 0.2452
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0544 - root_mean_squared_error: 0.2331
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0415 - root_mean_squared_error: 0.2037
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0368 - root_mean_squared_error: 0.1919
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0215 - root_mean_squared_error: 0.1468
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0289 - root_mean_squared_error: 0.1701
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0174 - root_mean_squared_error: 0.1320
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0263 - root_mean_squared_error: 0.1621
# Epoch 10/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246
# 1/1 [==============================] - 1s 578ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.1441 - root_mean_squared_error: 0.3796
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0653 - root_mean_squared_error: 0.2556
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0344 - root_mean_squared_error: 0.1855
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0401 - root_mean_squared_error: 0.2004
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0192 - root_mean_squared_error: 0.1384
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0275 - root_mean_squared_error: 0.1659
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0232 - root_mean_squared_error: 0.1525
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0174 - root_mean_squared_error: 0.1320
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0197 - root_mean_squared_error: 0.1405
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307
# 1/1 [==============================] - 0s 483ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 9ms/step - loss: 0.1596 - root_mean_squared_error: 0.3995
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0603 - root_mean_squared_error: 0.2456
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0343 - root_mean_squared_error: 0.1852
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0464 - root_mean_squared_error: 0.2153
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0389 - root_mean_squared_error: 0.1971
# Epoch 6/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0229 - root_mean_squared_error: 0.1513
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0307 - root_mean_squared_error: 0.1752
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0227 - root_mean_squared_error: 0.1508
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0192 - root_mean_squared_error: 0.1386
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 2/2 [==============================] - 2s 10ms/step - loss: 0.2460 - root_mean_squared_error: 0.4960
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0591 - root_mean_squared_error: 0.2430
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0890 - root_mean_squared_error: 0.2983
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0419 - root_mean_squared_error: 0.2047
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0396 - root_mean_squared_error: 0.1990
# Epoch 6/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0458 - root_mean_squared_error: 0.2140
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0353 - root_mean_squared_error: 0.1878
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0245 - root_mean_squared_error: 0.1564
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0278 - root_mean_squared_error: 0.1668
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0260 - root_mean_squared_error: 0.1614
# 1/1 [==============================] - 0s 499ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 9ms/step - loss: 0.2671 - root_mean_squared_error: 0.5168
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0669 - root_mean_squared_error: 0.2586
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0683 - root_mean_squared_error: 0.2613
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0311 - root_mean_squared_error: 0.1762
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0420 - root_mean_squared_error: 0.2049
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0303 - root_mean_squared_error: 0.1739
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0266 - root_mean_squared_error: 0.1632
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284
# 1/1 [==============================] - 1s 515ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 6ms/step - loss: 0.1201 - root_mean_squared_error: 0.3466
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1322 - root_mean_squared_error: 0.3637
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0426 - root_mean_squared_error: 0.2063
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0383 - root_mean_squared_error: 0.1957
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529
# Epoch 6/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0275 - root_mean_squared_error: 0.1658
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0211 - root_mean_squared_error: 0.1454
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0262 - root_mean_squared_error: 0.1619
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365
# 1/1 [==============================] - 1s 504ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.2918 - root_mean_squared_error: 0.5402
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0546 - root_mean_squared_error: 0.2336
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0844 - root_mean_squared_error: 0.2904
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0242 - root_mean_squared_error: 0.1555
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0372 - root_mean_squared_error: 0.1928
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0431 - root_mean_squared_error: 0.2076
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0204 - root_mean_squared_error: 0.1430
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0263 - root_mean_squared_error: 0.1621
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0239 - root_mean_squared_error: 0.1547
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0162 - root_mean_squared_error: 0.1271
# 1/1 [==============================] - 0s 472ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 6ms/step - loss: 0.1891 - root_mean_squared_error: 0.4349
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0650 - root_mean_squared_error: 0.2549
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0389 - root_mean_squared_error: 0.1972
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0511 - root_mean_squared_error: 0.2261
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0372 - root_mean_squared_error: 0.1928
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0197 - root_mean_squared_error: 0.1402
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0310 - root_mean_squared_error: 0.1759
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0241 - root_mean_squared_error: 0.1551
# 1/1 [==============================] - 0s 474ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 10ms/step - loss: 0.1416 - root_mean_squared_error: 0.3763
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0734 - root_mean_squared_error: 0.2709
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0340 - root_mean_squared_error: 0.1843
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0431 - root_mean_squared_error: 0.2076
# Epoch 5/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0253 - root_mean_squared_error: 0.1589
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1426
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0155 - root_mean_squared_error: 0.1247
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341
# 1/1 [==============================] - 0s 467ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.1736 - root_mean_squared_error: 0.4167
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0546 - root_mean_squared_error: 0.2336
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0267 - root_mean_squared_error: 0.1633
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0267 - root_mean_squared_error: 0.1635
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0174 - root_mean_squared_error: 0.1317
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0143 - root_mean_squared_error: 0.1198
# 1/1 [==============================] - 0s 493ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 6ms/step - loss: 0.2050 - root_mean_squared_error: 0.4527
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0755 - root_mean_squared_error: 0.2747
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0433 - root_mean_squared_error: 0.2080
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0461 - root_mean_squared_error: 0.2147
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0586 - root_mean_squared_error: 0.2420
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0380 - root_mean_squared_error: 0.1950
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0222 - root_mean_squared_error: 0.1489
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0317 - root_mean_squared_error: 0.1779
# Epoch 9/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0245 - root_mean_squared_error: 0.1565
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365
# 1/1 [==============================] - 1s 600ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2747 - root_mean_squared_error: 0.5241
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0971 - root_mean_squared_error: 0.3117
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0658 - root_mean_squared_error: 0.2564
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0339 - root_mean_squared_error: 0.1842
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0414 - root_mean_squared_error: 0.2034
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0294 - root_mean_squared_error: 0.1714
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1386
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311
# 1/1 [==============================] - 0s 481ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.1622 - root_mean_squared_error: 0.4027
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0714 - root_mean_squared_error: 0.2672
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0326 - root_mean_squared_error: 0.1807
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0432 - root_mean_squared_error: 0.2078
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0252 - root_mean_squared_error: 0.1588
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0236 - root_mean_squared_error: 0.1537
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0166 - root_mean_squared_error: 0.1290
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0186 - root_mean_squared_error: 0.1366
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268
# 1/1 [==============================] - 0s 492ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 11ms/step - loss: 0.2195 - root_mean_squared_error: 0.4685
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0758 - root_mean_squared_error: 0.2754
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0468 - root_mean_squared_error: 0.2163
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0468 - root_mean_squared_error: 0.2164
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0537 - root_mean_squared_error: 0.2317
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0302 - root_mean_squared_error: 0.1736
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0226 - root_mean_squared_error: 0.1502
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0309 - root_mean_squared_error: 0.1757
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0193 - root_mean_squared_error: 0.1390
# 1/1 [==============================] - 0s 480ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.2334 - root_mean_squared_error: 0.4832
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0513 - root_mean_squared_error: 0.2265
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0613 - root_mean_squared_error: 0.2476
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0340 - root_mean_squared_error: 0.1845
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0438 - root_mean_squared_error: 0.2094
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0289 - root_mean_squared_error: 0.1700
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0192 - root_mean_squared_error: 0.1387
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0301 - root_mean_squared_error: 0.1734
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0186 - root_mean_squared_error: 0.1364
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0178 - root_mean_squared_error: 0.1333
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.3289 - root_mean_squared_error: 0.5735
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0669 - root_mean_squared_error: 0.2586
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1248 - root_mean_squared_error: 0.3532
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0370 - root_mean_squared_error: 0.1923
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0708 - root_mean_squared_error: 0.2660
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0589 - root_mean_squared_error: 0.2426
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0354 - root_mean_squared_error: 0.1882
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0356 - root_mean_squared_error: 0.1888
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0380 - root_mean_squared_error: 0.1950
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0246 - root_mean_squared_error: 0.1569
# 1/1 [==============================] - 1s 502ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.3172 - root_mean_squared_error: 0.5632
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1091 - root_mean_squared_error: 0.3303
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0536 - root_mean_squared_error: 0.2315
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0668 - root_mean_squared_error: 0.2584
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0366 - root_mean_squared_error: 0.1912
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0480 - root_mean_squared_error: 0.2191
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0428 - root_mean_squared_error: 0.2068
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0280 - root_mean_squared_error: 0.1673
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0279 - root_mean_squared_error: 0.1670
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0264 - root_mean_squared_error: 0.1626
# 1/1 [==============================] - 1s 504ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 9ms/step - loss: 0.1840 - root_mean_squared_error: 0.4289
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0607 - root_mean_squared_error: 0.2463
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0339 - root_mean_squared_error: 0.1842
# Epoch 4/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0412 - root_mean_squared_error: 0.2031
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0448 - root_mean_squared_error: 0.2117
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0220 - root_mean_squared_error: 0.1483
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0286 - root_mean_squared_error: 0.1691
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0152 - root_mean_squared_error: 0.1231
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0211 - root_mean_squared_error: 0.1451
# 1/1 [==============================] - 1s 532ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.3004 - root_mean_squared_error: 0.5481
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1710 - root_mean_squared_error: 0.4135
# Epoch 3/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0491 - root_mean_squared_error: 0.2215
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0808 - root_mean_squared_error: 0.2842
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0379 - root_mean_squared_error: 0.1946
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0506 - root_mean_squared_error: 0.2249
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0472 - root_mean_squared_error: 0.2172
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0275 - root_mean_squared_error: 0.1659
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0282 - root_mean_squared_error: 0.1679
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0267 - root_mean_squared_error: 0.1634
# 1/1 [==============================] - 1s 512ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 6ms/step - loss: 0.3001 - root_mean_squared_error: 0.5478
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1357 - root_mean_squared_error: 0.3683
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0546 - root_mean_squared_error: 0.2337
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0719 - root_mean_squared_error: 0.2682
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0389 - root_mean_squared_error: 0.1973
# Epoch 6/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0453 - root_mean_squared_error: 0.2129
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0426 - root_mean_squared_error: 0.2065
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0271 - root_mean_squared_error: 0.1645
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0249 - root_mean_squared_error: 0.1578
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0290 - root_mean_squared_error: 0.1702
# 1/1 [==============================] - 0s 479ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 7ms/step - loss: 0.1532 - root_mean_squared_error: 0.3915
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0539 - root_mean_squared_error: 0.2322
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0278 - root_mean_squared_error: 0.1667
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0385 - root_mean_squared_error: 0.1962
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0234 - root_mean_squared_error: 0.1531
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0199 - root_mean_squared_error: 0.1411
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0183 - root_mean_squared_error: 0.1352
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208
# 1/1 [==============================] - 1s 523ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.1629 - root_mean_squared_error: 0.4036
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1014 - root_mean_squared_error: 0.3185
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0325 - root_mean_squared_error: 0.1801
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0517 - root_mean_squared_error: 0.2274
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0279 - root_mean_squared_error: 0.1670
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0242 - root_mean_squared_error: 0.1556
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0263 - root_mean_squared_error: 0.1621
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0209 - root_mean_squared_error: 0.1445
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0209 - root_mean_squared_error: 0.1447
# 1/1 [==============================] - 1s 549ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 6ms/step - loss: 0.1739 - root_mean_squared_error: 0.4170
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0846 - root_mean_squared_error: 0.2908
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0492 - root_mean_squared_error: 0.2218
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0634 - root_mean_squared_error: 0.2518
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0324 - root_mean_squared_error: 0.1799
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0365 - root_mean_squared_error: 0.1909
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0286 - root_mean_squared_error: 0.1691
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0195 - root_mean_squared_error: 0.1398
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0264 - root_mean_squared_error: 0.1625
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0206 - root_mean_squared_error: 0.1434
# 1/1 [==============================] - 1s 552ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.2102 - root_mean_squared_error: 0.4585
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0492 - root_mean_squared_error: 0.2219
# Epoch 3/10
# ...
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0481 - root_mean_squared_error: 0.2193
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0393 - root_mean_squared_error: 0.1982
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0202 - root_mean_squared_error: 0.1420
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0340 - root_mean_squared_error: 0.1843
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0213 - root_mean_squared_error: 0.1460
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0230 - root_mean_squared_error: 0.1517
# 1/1 [==============================] - 0s 494ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.2439 - root_mean_squared_error: 0.4939
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0556 - root_mean_squared_error: 0.2357
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0578 - root_mean_squared_error: 0.2405
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0340 - root_mean_squared_error: 0.1843
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0454 - root_mean_squared_error: 0.2131
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0317 - root_mean_squared_error: 0.1781
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0272 - root_mean_squared_error: 0.1650
# Epoch 8/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0273 - root_mean_squared_error: 0.1653
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0207 - root_mean_squared_error: 0.1440
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296
# 1/1 [==============================] - 1s 609ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 9ms/step - loss: 0.1644 - root_mean_squared_error: 0.4054
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0649 - root_mean_squared_error: 0.2548
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0383 - root_mean_squared_error: 0.1956
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0353 - root_mean_squared_error: 0.1880
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0230 - root_mean_squared_error: 0.1518
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170 - root_mean_squared_error: 0.1304
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0205 - root_mean_squared_error: 0.1433
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0168 - root_mean_squared_error: 0.1298
# 1/1 [==============================] - 0s 489ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 4ms/step - loss: 0.2525 - root_mean_squared_error: 0.5025
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0631 - root_mean_squared_error: 0.2513
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0927 - root_mean_squared_error: 0.3044
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0364 - root_mean_squared_error: 0.1908
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0493 - root_mean_squared_error: 0.2220
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0486 - root_mean_squared_error: 0.2205
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0289 - root_mean_squared_error: 0.1699
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0231 - root_mean_squared_error: 0.1521
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0302 - root_mean_squared_error: 0.1737
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0205 - root_mean_squared_error: 0.1431
# 1/1 [==============================] - 0s 485ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2814 - root_mean_squared_error: 0.5305
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2123 - root_mean_squared_error: 0.4608
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1171 - root_mean_squared_error: 0.3421
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0511 - root_mean_squared_error: 0.2261
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0898 - root_mean_squared_error: 0.2996
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0477 - root_mean_squared_error: 0.2184
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0507 - root_mean_squared_error: 0.2251
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0578 - root_mean_squared_error: 0.2404
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0504 - root_mean_squared_error: 0.2245
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0391 - root_mean_squared_error: 0.1976
# 1/1 [==============================] - 0s 479ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 4ms/step - loss: 0.2038 - root_mean_squared_error: 0.4515
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0694 - root_mean_squared_error: 0.2635
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0546 - root_mean_squared_error: 0.2337
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0417 - root_mean_squared_error: 0.2041
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0506 - root_mean_squared_error: 0.2249
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0375 - root_mean_squared_error: 0.1937
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0271 - root_mean_squared_error: 0.1647
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0299 - root_mean_squared_error: 0.1728
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0284 - root_mean_squared_error: 0.1685
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0216 - root_mean_squared_error: 0.1469
# 1/1 [==============================] - 0s 465ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.3290 - root_mean_squared_error: 0.5736
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0493 - root_mean_squared_error: 0.2221
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0657 - root_mean_squared_error: 0.2562
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0396 - root_mean_squared_error: 0.1991
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0426 - root_mean_squared_error: 0.2064
# Epoch 6/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0299 - root_mean_squared_error: 0.1730
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0222 - root_mean_squared_error: 0.1489
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0268 - root_mean_squared_error: 0.1638
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359
# 1/1 [==============================] - 1s 506ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 10ms/step - loss: 0.1852 - root_mean_squared_error: 0.4303
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0604 - root_mean_squared_error: 0.2457
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0452 - root_mean_squared_error: 0.2127
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0425 - root_mean_squared_error: 0.2061
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0477 - root_mean_squared_error: 0.2184
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0281 - root_mean_squared_error: 0.1677
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0255 - root_mean_squared_error: 0.1596
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0293 - root_mean_squared_error: 0.1712
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.1340
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0187 - root_mean_squared_error: 0.1369
# 1/1 [==============================] - 1s 504ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.1398 - root_mean_squared_error: 0.3739
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0808 - root_mean_squared_error: 0.2843
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0380 - root_mean_squared_error: 0.1949
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0463 - root_mean_squared_error: 0.2152
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0351 - root_mean_squared_error: 0.1875
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0228 - root_mean_squared_error: 0.1510
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0302 - root_mean_squared_error: 0.1737
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0208 - root_mean_squared_error: 0.1442
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0189 - root_mean_squared_error: 0.1373
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0213 - root_mean_squared_error: 0.1459
# 1/1 [==============================] - 0s 472ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.2930 - root_mean_squared_error: 0.5413
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1004 - root_mean_squared_error: 0.3168
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0606 - root_mean_squared_error: 0.2461
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0375 - root_mean_squared_error: 0.1937
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0327 - root_mean_squared_error: 0.1809
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0432 - root_mean_squared_error: 0.2079
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0293 - root_mean_squared_error: 0.1712
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0279 - root_mean_squared_error: 0.1671
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0182 - root_mean_squared_error: 0.1350
# 1/1 [==============================] - 1s 516ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.1481 - root_mean_squared_error: 0.3848
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0723 - root_mean_squared_error: 0.2688
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0389 - root_mean_squared_error: 0.1971
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0425 - root_mean_squared_error: 0.2061
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0207 - root_mean_squared_error: 0.1439
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0321 - root_mean_squared_error: 0.1792
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0202 - root_mean_squared_error: 0.1421
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0272 - root_mean_squared_error: 0.1649
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0200 - root_mean_squared_error: 0.1413
# 1/1 [==============================] - 0s 472ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.2654 - root_mean_squared_error: 0.5152
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0809 - root_mean_squared_error: 0.2845
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0684 - root_mean_squared_error: 0.2615
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0424 - root_mean_squared_error: 0.2059
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0401 - root_mean_squared_error: 0.2001
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0487 - root_mean_squared_error: 0.2207
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0347 - root_mean_squared_error: 0.1862
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0298 - root_mean_squared_error: 0.1726
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579
# 1/1 [==============================] - 0s 468ms/step
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.3285 - root_mean_squared_error: 0.5731
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0682 - root_mean_squared_error: 0.2611
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0490 - root_mean_squared_error: 0.2213
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0348 - root_mean_squared_error: 0.1865
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0245 - root_mean_squared_error: 0.1564
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0220 - root_mean_squared_error: 0.1482
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0197 - root_mean_squared_error: 0.1404
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1384
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0184 - root_mean_squared_error: 0.1358
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0160 - root_mean_squared_error: 0.1267
# 1/1 [==============================] - 0s 463ms/step
# Epoch 1/10
# 2/2 [==============================] - 2s 13ms/step - loss: 0.2493 - root_mean_squared_error: 0.4993
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0852 - root_mean_squared_error: 0.2918
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0708 - root_mean_squared_error: 0.2661
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0400 - root_mean_squared_error: 0.2000
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0465 - root_mean_squared_error: 0.2156
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0431 - root_mean_squared_error: 0.2076
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0253 - root_mean_squared_error: 0.1592
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0312 - root_mean_squared_error: 0.1767
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0246 - root_mean_squared_error: 0.1567
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0210 - root_mean_squared_error: 0.1451
# 1/1 [==============================] - 0s 470ms/step

# %%
df_res = pd.DataFrame(
    {'MAPE': MAPE,
     'Direction': correction})
df_res.describe()
# Out:
#              MAPE   Direction
# count  100.000000  100.000000
# mean     1.578120    0.648824
# std      1.085455    0.056369
# min      0.627000    0.529412
# 25%      0.851500    0.588235
# 50%      1.179000    0.647059
# 75%      2.143750    0.705882
# max      8.475000    0.764706

# %%
plt.title("MAPE")
plt.plot(df_res['MAPE'])
plt.show()

# %%
plt.title("Direction")
plt.plot(df_res['Direction'])
plt.show()
